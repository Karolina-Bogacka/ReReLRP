# %%
path_lwf = '/home/karokaro/research-repositories/FACIL/results/pathmnist_lwf_final_pathmnist'

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(path_lwf) if isfile(join(path_lwf, f))]
onlyfiles
# Out:
# ['raw_log-2025-02-05-01-12.txt',
#  'stdout-2025-02-05-02-31.txt',
#  'stderr-2025-02-05-00-39.txt',
#  'stderr-2025-02-05-02-31.txt',
#  'raw_log-2025-02-04-23-32.txt',
#  'args-2025-02-05-00-14.txt',
#  'args-2025-02-05-02-31.txt',
#  'args-2025-02-04-23-50.txt',
#  'raw_log-2025-02-05-00-39.txt',
#  'stderr-2025-02-05-01-32.txt',
#  'raw_log-2025-02-05-02-03.txt',
#  'stdout-2025-02-05-00-39.txt',
#  'args-2025-02-05-02-03.txt',
#  'stderr-2025-02-05-00-14.txt',
#  'args-2025-02-05-01-12.txt',
#  'raw_log-2025-02-05-01-32.txt',
#  'stderr-2025-02-05-01-12.txt',
#  'raw_log-2025-02-05-00-14.txt',
#  'raw_log-2025-02-04-23-50.txt',
#  'raw_log-2025-02-05-02-31.txt',
#  'args-2025-02-05-01-32.txt',
#  'args-2025-02-04-23-32.txt',
#  'stdout-2025-02-04-23-50.txt',
#  'stdout-2025-02-05-01-12.txt',
#  'stderr-2025-02-04-23-32.txt',
#  'stderr-2025-02-04-23-50.txt',
#  'stderr-2025-02-04-23-04.txt',
#  'raw_log-2025-02-04-23-04.txt',
#  'stdout-2025-02-05-02-03.txt',
#  'stderr-2025-02-05-02-03.txt',
#  'stdout-2025-02-05-00-14.txt',
#  'stdout-2025-02-05-01-32.txt',
#  'stdout-2025-02-04-23-32.txt',
#  'stdout-2025-02-04-23-04.txt',
#  'args-2025-02-05-00-39.txt',
#  'args-2025-02-04-23-04.txt']

# %%
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_lwf, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_lwf, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
res_dict
# Out:
# {'2025-02-05-01-12.txt': [{'group': 'valid',
#    'iter': 1,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 1.0072144003312336},
#   {'group': 'valid',
#    'iter': 1,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 80.81395348837209},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 5},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 1.1058133848714764},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 32.660738714090286},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 4},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 0.823944831554932},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 62.243502051983576},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 5},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 1.1190967116245003},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 32.523939808481536},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 4},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 1.0300603581518546},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 51.641586867305065},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 3},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 1.0911805867007265},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 35.43091655266758},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 2},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-12',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 7,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 1.0879673137547379},
#   {'group': 'valid',
#    'iter': 7,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 27.667578659370722},
#   {'group': 'train',
#    'iter': 7,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 1},
#   {'group': 'train',
#    'iter': 7,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 8,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.9356294956807398},
#   {'group': 'valid',
#    'iter': 8,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 68.9124487004104},
#   {'group': 'train',
#    'iter': 8,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 8,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 9,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.9003727966065935},
#   {'group': 'valid',
#    'iter': 9,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 70.38303693570451},
#   {'group': 'train',
#    'iter': 9,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 4},
#   {'group': 'train',
#    'iter': 9,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 10,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.8577505985297844},
#   {'group': 'valid',
#    'iter': 10,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 78.69357045143639},
#   {'group': 'train',
#    'iter': 10,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 3},
#   {'group': 'train',
#    'iter': 10,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 11,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.9607269690561882},
#   {'group': 'valid',
#    'iter': 11,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 46.75102599179207},
#   {'group': 'train',
#    'iter': 11,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 2},
#   {'group': 'train',
#    'iter': 11,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 12,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 1.762513186471733},
#   {'group': 'valid',
#    'iter': 12,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 47.70861833105335},
#   {'group': 'train',
#    'iter': 12,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 1},
#   {'group': 'train',
#    'iter': 12,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 13,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.5378373074874017},
#   {'group': 'valid',
#    'iter': 13,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 82.45554035567716},
#   {'group': 'train',
#    'iter': 13,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 13,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 14,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.47060311925068765},
#   {'group': 'valid',
#    'iter': 14,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 82.3187414500684},
#   {'group': 'train',
#    'iter': 14,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 14,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 15,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.5031553659735887},
#   {'group': 'valid',
#    'iter': 15,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 83.78932968536252},
#   {'group': 'train',
#    'iter': 15,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 4},
#   {'group': 'train',
#    'iter': 15,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 16,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.4349529947448527},
#   {'group': 'valid',
#    'iter': 16,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 82.5923392612859},
#   {'group': 'train',
#    'iter': 16,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 16,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 17,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.5261150828464576},
#   {'group': 'valid',
#    'iter': 17,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 79.30916552667578},
#   {'group': 'train',
#    'iter': 17,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 4},
#   {'group': 'train',
#    'iter': 17,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 18,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.5095861468530386},
#   {'group': 'valid',
#    'iter': 18,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 82.21614227086184},
#   {'group': 'train',
#    'iter': 18,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 3},
#   {'group': 'train',
#    'iter': 18,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.3762786827278202},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 84.61012311901504},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.3750228872866702},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 87.41450068399452},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.39559134906196075},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 84.02872777017784},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 4},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.35398704502553197},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 87.58549931600548},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 5},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.35500337585052616},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 87.34610123119015},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 4},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.4794926676394675},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 83.5499316005472},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 3},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.3123137042558307},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 88.88508891928865},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 5},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.32183315877059904},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 88.406292749658},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 4},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.374233343125042},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 85.3625170998632},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 3},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.4383331867477636},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 82.14774281805745},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 2},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.32548184623551923},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 88.20109439124487},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 1},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.2581297625799023},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 89.70588235294117},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 5},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.31325629704138813},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 88.57729138166894},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 4},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 1.3997271504513054},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 56.83994528043775},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 3},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.2873919944185891},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 88.88508891928865},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 2},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.3151832848950385},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 91.89466484268127},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 1},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.27869884543396056},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 89.05608755129958},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.2537385984419472},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 89.77428180574556},
#   {'group': 'train',
#    'iter': 36,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 36,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 37,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.24668023043226772},
#   {'group': 'valid',
#    'iter': 37,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 89.60328317373461},
#   {'group': 'train',
#    'iter': 37,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 37,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 38,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.2610406758806448},
#   {'group': 'valid',
#    'iter': 38,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 89.84268125854993},
#   {'group': 'train',
#    'iter': 38,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 4},
#   {'group': 'train',
#    'iter': 38,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 39,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.23430804673852412},
#   {'group': 'valid',
#    'iter': 39,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 89.87688098495212},
#   {'group': 'train',
#    'iter': 39,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 39,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 40,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.24488197161055458},
#   {'group': 'valid',
#    'iter': 40,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 89.84268125854993},
#   {'group': 'train',
#    'iter': 40,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 4},
#   {'group': 'train',
#    'iter': 40,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 41,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.22552789201407034},
#   {'group': 'valid',
#    'iter': 41,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 94.63064295485636},
#   {'group': 'train',
#    'iter': 41,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 41,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 42,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.24637380146539978},
#   {'group': 'valid',
#    'iter': 42,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 90.11627906976744},
#   {'group': 'train',
#    'iter': 42,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 4},
#   {'group': 'train',
#    'iter': 42,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 43,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.22050284599393566},
#   {'group': 'valid',
#    'iter': 43,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 90.15047879616964},
#   {'group': 'train',
#    'iter': 43,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 43,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 44,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.2126338171037538},
#   {'group': 'valid',
#    'iter': 44,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 90.66347469220246},
#   {'group': 'train',
#    'iter': 44,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 44,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 45,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.22121435320246888},
#   {'group': 'valid',
#    'iter': 45,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 90.2530779753762},
#   {'group': 'train',
#    'iter': 45,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 4},
#   {'group': 'train',
#    'iter': 45,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 46,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.2473374276680594},
#   {'group': 'valid',
#    'iter': 46,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 89.97948016415869},
#   {'group': 'train',
#    'iter': 46,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 3},
#   {'group': 'train',
#    'iter': 46,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 47,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.2434403848224071},
#   {'group': 'valid',
#    'iter': 47,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 90.08207934336525},
#   {'group': 'train',
#    'iter': 47,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 2},
#   {'group': 'train',
#    'iter': 47,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 48,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.21591721332431982},
#   {'group': 'valid',
#    'iter': 48,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 90.45827633378933},
#   {'group': 'train',
#    'iter': 48,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 1},
#   {'group': 'train',
#    'iter': 48,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 49,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.21644207967697515},
#   {'group': 'valid',
#    'iter': 49,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 90.56087551299589},
#   {'group': 'train',
#    'iter': 49,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 49,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 50,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.20751710539803458},
#   {'group': 'valid',
#    'iter': 50,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 93.12585499316005},
#   {'group': 'train',
#    'iter': 50,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 50,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 51,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.21960308375257473},
#   {'group': 'valid',
#    'iter': 51,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 90.2872777017784},
#   {'group': 'train',
#    'iter': 51,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 4},
#   {'group': 'train',
#    'iter': 51,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 52,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.20750063733183735},
#   {'group': 'valid',
#    'iter': 52,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 90.80027359781123},
#   {'group': 'train',
#    'iter': 52,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 52,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 53,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.20231563868013844},
#   {'group': 'valid',
#    'iter': 53,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 94.35704514363886},
#   {'group': 'train',
#    'iter': 53,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 53,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 54,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.2035942579506197},
#   {'group': 'valid',
#    'iter': 54,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 93.74145006839946},
#   {'group': 'train',
#    'iter': 54,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 4},
#   {'group': 'train',
#    'iter': 54,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 55,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.20782524174035982},
#   {'group': 'valid',
#    'iter': 55,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 90.93707250341997},
#   {'group': 'train',
#    'iter': 55,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 3},
#   {'group': 'train',
#    'iter': 55,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 56,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.19429209793722907},
#   {'group': 'valid',
#    'iter': 56,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 94.93844049247606},
#   {'group': 'train',
#    'iter': 56,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 56,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 57,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.19606384440298447},
#   {'group': 'valid',
#    'iter': 57,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 94.8016415868673},
#   {'group': 'train',
#    'iter': 57,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 4},
#   {'group': 'train',
#    'iter': 57,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 58,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.19037273273422356},
#   {'group': 'valid',
#    'iter': 58,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 94.90424076607387},
#   {'group': 'train',
#    'iter': 58,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 58,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 59,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.2090522650369378},
#   {'group': 'valid',
#    'iter': 59,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 93.36525307797537},
#   {'group': 'train',
#    'iter': 59,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 4},
#   {'group': 'train',
#    'iter': 59,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 60,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.1881407266622855},
#   {'group': 'valid',
#    'iter': 60,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 95.10943912448701},
#   {'group': 'train',
#    'iter': 60,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 60,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 61,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.1860308519140314},
#   {'group': 'valid',
#    'iter': 61,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 95.04103967168263},
#   {'group': 'train',
#    'iter': 61,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 61,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 62,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.19511219912123257},
#   {'group': 'valid',
#    'iter': 62,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 94.35704514363886},
#   {'group': 'train',
#    'iter': 62,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 4},
#   {'group': 'train',
#    'iter': 62,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-16',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 63,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.18044472284992155},
#   {'group': 'valid',
#    'iter': 63,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 95.14363885088919},
#   {'group': 'train',
#    'iter': 63,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 5},
#   {'group': 'train',
#    'iter': 63,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 64,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.1881167184556395},
#   {'group': 'valid',
#    'iter': 64,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 93.84404924760602},
#   {'group': 'train',
#    'iter': 64,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 4},
#   {'group': 'train',
#    'iter': 64,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 65,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.23799587704659161},
#   {'group': 'valid',
#    'iter': 65,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 90.76607387140902},
#   {'group': 'train',
#    'iter': 65,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 3},
#   {'group': 'train',
#    'iter': 65,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 66,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.18340721267763468},
#   {'group': 'valid',
#    'iter': 66,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 94.90424076607387},
#   {'group': 'train',
#    'iter': 66,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 2},
#   {'group': 'train',
#    'iter': 66,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 67,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.18035015555559855},
#   {'group': 'valid',
#    'iter': 67,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 95.00683994528045},
#   {'group': 'train',
#    'iter': 67,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 5},
#   {'group': 'train',
#    'iter': 67,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 68,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.2241916987030842},
#   {'group': 'valid',
#    'iter': 68,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 90.90287277701779},
#   {'group': 'train',
#    'iter': 68,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 4},
#   {'group': 'train',
#    'iter': 68,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 69,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.19756583250783863},
#   {'group': 'valid',
#    'iter': 69,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 91.27906976744185},
#   {'group': 'train',
#    'iter': 69,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 3},
#   {'group': 'train',
#    'iter': 69,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 70,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.18631367912329988},
#   {'group': 'valid',
#    'iter': 70,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 94.66484268125855},
#   {'group': 'train',
#    'iter': 70,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 2},
#   {'group': 'train',
#    'iter': 70,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 71,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.20928483038488394},
#   {'group': 'valid',
#    'iter': 71,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 91.24487004103968},
#   {'group': 'train',
#    'iter': 71,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 1},
#   {'group': 'train',
#    'iter': 71,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 72,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.19774836116303499},
#   {'group': 'valid',
#    'iter': 72,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 91.17647058823529},
#   {'group': 'train',
#    'iter': 72,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 5},
#   {'group': 'train',
#    'iter': 72,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 73,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.18143133411410733},
#   {'group': 'valid',
#    'iter': 73,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 95.00683994528045},
#   {'group': 'train',
#    'iter': 73,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 4},
#   {'group': 'train',
#    'iter': 73,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 74,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.17618104872560045},
#   {'group': 'valid',
#    'iter': 74,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 95.04103967168263},
#   {'group': 'train',
#    'iter': 74,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 5},
#   {'group': 'train',
#    'iter': 74,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 75,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.17863710405032385},
#   {'group': 'valid',
#    'iter': 75,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 95.04103967168263},
#   {'group': 'train',
#    'iter': 75,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 4},
#   {'group': 'train',
#    'iter': 75,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 76,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.177025966122033},
#   {'group': 'valid',
#    'iter': 76,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 95.0752393980848},
#   {'group': 'train',
#    'iter': 76,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 3},
#   {'group': 'train',
#    'iter': 76,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-17',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 77,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.1761907011005523},
#   {'group': 'valid',
#    'iter': 77,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 95.00683994528045},
#   {'group': 'train',
#    'iter': 77,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 2},
#   {'group': 'train',
#    'iter': 77,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 78,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.17501697245929212},
#   {'group': 'valid',
#    'iter': 78,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 95.10943912448701},
#   {'group': 'train',
#    'iter': 78,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 5},
#   {'group': 'train',
#    'iter': 78,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 79,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.17943212823119276},
#   {'group': 'valid',
#    'iter': 79,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 94.97264021887824},
#   {'group': 'train',
#    'iter': 79,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 4},
#   {'group': 'train',
#    'iter': 79,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 80,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.17420635570131152},
#   {'group': 'valid',
#    'iter': 80,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 95.04103967168263},
#   {'group': 'train',
#    'iter': 80,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 5},
#   {'group': 'train',
#    'iter': 80,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 81,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.17418326629088776},
#   {'group': 'valid',
#    'iter': 81,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 95.04103967168263},
#   {'group': 'train',
#    'iter': 81,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 5},
#   {'group': 'train',
#    'iter': 81,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 82,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.17213541242802355},
#   {'group': 'valid',
#    'iter': 82,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 95.10943912448701},
#   {'group': 'train',
#    'iter': 82,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 5},
#   {'group': 'train',
#    'iter': 82,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 83,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.17415041147276414},
#   {'group': 'valid',
#    'iter': 83,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 95.00683994528045},
#   {'group': 'train',
#    'iter': 83,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 4},
#   {'group': 'train',
#    'iter': 83,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 84,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.1793885714031766},
#   {'group': 'valid',
#    'iter': 84,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 94.59644322845418},
#   {'group': 'train',
#    'iter': 84,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 3},
#   {'group': 'train',
#    'iter': 84,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 85,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.17063164540786913},
#   {'group': 'valid',
#    'iter': 85,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 95.17783857729138},
#   {'group': 'train',
#    'iter': 85,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 5},
#   {'group': 'train',
#    'iter': 85,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 86,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.178594892362971},
#   {'group': 'valid',
#    'iter': 86,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 94.76744186046511},
#   {'group': 'train',
#    'iter': 86,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 4},
#   {'group': 'train',
#    'iter': 86,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 87,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.1759216348690308},
#   {'group': 'valid',
#    'iter': 87,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 94.8016415868673},
#   {'group': 'train',
#    'iter': 87,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 3},
#   {'group': 'train',
#    'iter': 87,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 88,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.17112907350430248},
#   {'group': 'valid',
#    'iter': 88,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 95.10943912448701},
#   {'group': 'train',
#    'iter': 88,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 2},
#   {'group': 'train',
#    'iter': 88,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 89,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.17015033075649663},
#   {'group': 'valid',
#    'iter': 89,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 95.14363885088919},
#   {'group': 'train',
#    'iter': 89,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 5},
#   {'group': 'train',
#    'iter': 89,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 90,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.17070708395314446},
#   {'group': 'valid',
#    'iter': 90,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 95.21203830369357},
#   {'group': 'train',
#    'iter': 90,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 4},
#   {'group': 'train',
#    'iter': 90,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-18',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 91,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-19',
#    'value': 0.173842566120967},
#   {'group': 'valid',
#    'iter': 91,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-19',
#    'value': 94.87004103967168},
#   {'group': 'train',
#    'iter': 91,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-19',
#    'value': 3},
#   {'group': 'train',
#    'iter': 91,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-19',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 92,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-19',
#    'value': 0.16638760045476553},
#   {'group': 'valid',
#    'iter': 92,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-19',
#    'value': 95.21203830369357},
#   {'group': 'train',
#    'iter': 92,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-19',
#    'value': 5},
#   {'group': 'train',
#    'iter': 92,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-19',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 93,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-01-19',
#    'value': 0.1688116409098564},
#   {'group': 'valid',
#    'iter': 93,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-01-19',
#    'value': 95.17783857729138},
#   {'group': 'train',
#    'iter': 93,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-01-19',
#    'value': 4},
#   {'group': 'train',
#    'iter': 93,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-01-19',
# ...
#    'iter': 138,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 84.89951113525258},
#   {'group': 'train',
#    'iter': 138,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 2},
#   {'group': 'train',
#    'iter': 138,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 139,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7222021468497696},
#   {'group': 'valid',
#    'iter': 139,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.00814774579032},
#   {'group': 'train',
#    'iter': 139,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 1},
#   {'group': 'train',
#    'iter': 139,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 140,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7188901154649187},
#   {'group': 'valid',
#    'iter': 140,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.33405757740358},
#   {'group': 'train',
#    'iter': 140,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 5},
#   {'group': 'train',
#    'iter': 140,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 141,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7185809493129632},
#   {'group': 'valid',
#    'iter': 141,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.27973927213472},
#   {'group': 'train',
#    'iter': 141,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 5},
#   {'group': 'train',
#    'iter': 141,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 142,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7202795692787812},
#   {'group': 'valid',
#    'iter': 142,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.11678435632808},
#   {'group': 'train',
#    'iter': 142,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 4},
#   {'group': 'train',
#    'iter': 142,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 143,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7166732343754517},
#   {'group': 'valid',
#    'iter': 143,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.71428571428571},
#   {'group': 'train',
#    'iter': 143,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 5},
#   {'group': 'train',
#    'iter': 143,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 144,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7161786237338003},
#   {'group': 'valid',
#    'iter': 144,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.71428571428571},
#   {'group': 'train',
#    'iter': 144,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 5},
#   {'group': 'train',
#    'iter': 144,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 145,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7162407731828581},
#   {'group': 'valid',
#    'iter': 145,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.44269418794134},
#   {'group': 'train',
#    'iter': 145,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 4},
#   {'group': 'train',
#    'iter': 145,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 146,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7173002162166162},
#   {'group': 'valid',
#    'iter': 146,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.11678435632808},
#   {'group': 'train',
#    'iter': 146,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 3},
#   {'group': 'train',
#    'iter': 146,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 147,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7173673235677235},
#   {'group': 'valid',
#    'iter': 147,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.17110266159695},
#   {'group': 'train',
#    'iter': 147,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 2},
#   {'group': 'train',
#    'iter': 147,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 148,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7167655191364527},
#   {'group': 'valid',
#    'iter': 148,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.22542096686584},
#   {'group': 'train',
#    'iter': 148,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 1},
#   {'group': 'train',
#    'iter': 148,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 149,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7169868415752745},
#   {'group': 'valid',
#    'iter': 149,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.11678435632808},
#   {'group': 'train',
#    'iter': 149,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 5},
#   {'group': 'train',
#    'iter': 149,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.00041152263374485596},
#   {'group': 'valid',
#    'iter': 150,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7187191818085525},
#   {'group': 'valid',
#    'iter': 150,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.33405757740358},
#   {'group': 'train',
#    'iter': 150,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 4},
#   {'group': 'train',
#    'iter': 150,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.00041152263374485596},
#   {'group': 'valid',
#    'iter': 151,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7188524803281283},
#   {'group': 'valid',
#    'iter': 151,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.27973927213472},
#   {'group': 'train',
#    'iter': 151,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 3},
#   {'group': 'train',
#    'iter': 151,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.00041152263374485596},
#   {'group': 'valid',
#    'iter': 152,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.719916721681484},
#   {'group': 'valid',
#    'iter': 152,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.22542096686584},
#   {'group': 'train',
#    'iter': 152,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 2},
#   {'group': 'train',
#    'iter': 152,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.00041152263374485596},
#   {'group': 'valid',
#    'iter': 153,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.7177872899302576},
#   {'group': 'valid',
#    'iter': 153,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 85.11678435632808},
#   {'group': 'train',
#    'iter': 153,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 1},
#   {'group': 'train',
#    'iter': 153,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-19',
#    'value': 0.00041152263374485596},
#   {'group': 'valid',
#    'iter': 154,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.7191864285114211},
#   {'group': 'valid',
#    'iter': 154,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 85.22542096686584},
#   {'group': 'train',
#    'iter': 154,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 154,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.00013717421124828533},
#   {'group': 'valid',
#    'iter': 155,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.7178731744604095},
#   {'group': 'valid',
#    'iter': 155,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 85.11678435632808},
#   {'group': 'train',
#    'iter': 155,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 155,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.00013717421124828533},
#   {'group': 'valid',
#    'iter': 156,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.7184770217024716},
#   {'group': 'valid',
#    'iter': 156,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 85.22542096686584},
#   {'group': 'train',
#    'iter': 156,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 3},
#   {'group': 'train',
#    'iter': 156,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.00013717421124828533},
#   {'group': 'valid',
#    'iter': 157,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.7187263520109725},
#   {'group': 'valid',
#    'iter': 157,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 85.33405757740358},
#   {'group': 'train',
#    'iter': 157,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 2},
#   {'group': 'train',
#    'iter': 157,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.00013717421124828533},
#   {'group': 'valid',
#    'iter': 158,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.7184436995331714},
#   {'group': 'valid',
#    'iter': 158,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 85.22542096686584},
#   {'group': 'train',
#    'iter': 158,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 1},
#   {'group': 'train',
#    'iter': 158,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.00013717421124828533},
#   {'group': 'valid',
#    'iter': 159,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.7188799561915483},
#   {'group': 'valid',
#    'iter': 159,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 85.27973927213472},
#   {'group': 'test',
#    'iter': 0,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 7.600379866767799},
#   {'group': 'test',
#    'iter': 0,
#    'name': 'acc_taw',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 65.88748019017433},
#   {'group': 'test',
#    'iter': 0,
#    'name': 'acc_tag',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.0},
#   {'group': 'test',
#    'iter': 0,
#    'name': 'forg_taw',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 33.359746434231376},
#   {'group': 'test',
#    'iter': 0,
#    'name': 'forg_tag',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 99.2472266244057},
#   {'group': 'test',
#    'iter': 1,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 1.2523970055394433},
#   {'group': 'test',
#    'iter': 1,
#    'name': 'acc_taw',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 67.6452965847813},
#   {'group': 'test',
#    'iter': 1,
#    'name': 'acc_tag',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 67.6452965847813},
#   {'group': 'test',
#    'iter': 1,
#    'name': 'forg_taw',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.0},
#   {'group': 'test',
#    'iter': 1,
#    'name': 'forg_tag',
#    'task': 1,
#    'time': '2025-02-04-23-20',
#    'value': 0.0},
#   {'group': 'valid',
#    'iter': 1,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 1.1572592963492865},
#   {'group': 'valid',
#    'iter': 1,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 60.687593423019436},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 1.1713368812484057},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 60.687593423019436},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 1.0987275060160455},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 60.687593423019436},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 1.1280739079320021},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 39.31240657698057},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 1.102397963723913},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 60.687593423019436},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 3},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 1.1035978782812517},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 60.687593423019436},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 2},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 7,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 1.1480625180623159},
#   {'group': 'valid',
#    'iter': 7,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 60.687593423019436},
#   {'group': 'train',
#    'iter': 7,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 1},
#   {'group': 'train',
#    'iter': 7,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 8,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-04-23-20',
#    'value': 1.0860355379097961},
#   ...]}

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
len(res_dict)
# Out:
# 3

# %%
import pandas as pd
import numpy as np
from itertools import chain
data = pd.DataFrame({'Approach': list(chain.from_iterable([['LWF' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
import seaborn as sns
sns.lineplot( data,  x='Task', y='Average Accuracy', ci=None)
# Out:
# /tmp/ipykernel_16290/1207693049.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot( data,  x='Task', y='Average Accuracy', ci=None)
# <Axes: xlabel='Task', ylabel='Average Accuracy'>

# %%
data.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# LWF      0                97.79                 NaN
#          1                88.34                4.12
#          2                62.84               41.39
#          3                65.84               30.86

# %%
path_ewc = '/home/karokaro/research-repositories/FACIL/results/pathmnist_ewc_final_pathmnist'

# %%
onlyfiles = [f for f in listdir(path_ewc) if isfile(join(path_ewc, f))]
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_ewc, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_ewc, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
data_ewc = pd.DataFrame({'Approach': list(chain.from_iterable([['EWC' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
sns.lineplot( data_ewc,  x='Task', y='Average Accuracy')
# Out:
# <Axes: xlabel='Task', ylabel='Average Accuracy'>

# %%
data_ewc.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# EWC      0                98.85                 NaN
#          1                74.33               23.09
#          2                56.88               46.18
#          3                69.83               22.50

# %%
path_lwm = '/home/karokaro/research-repositories/FACIL/results/pathmnist_lwm_final_pathmnist'

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(path_lwm) if isfile(join(path_lwm, f))]
onlyfiles
# Out:
# ['stderr-2025-02-05-23-30.txt',
#  'stderr-2025-02-06-00-28.txt',
#  'stdout-2025-02-05-21-01.txt',
#  'stderr-2025-02-05-22-12.txt',
#  'raw_log-2025-02-05-19-42.txt',
#  'args-2025-02-06-00-28.txt',
#  'raw_log-2025-02-05-18-07.txt',
#  'raw_log-2025-02-05-22-12.txt',
#  'stdout-2025-02-05-22-12.txt',
#  'args-2025-02-05-21-01.txt',
#  'stdout-2025-02-05-19-42.txt',
#  'args-2025-02-05-21-41.txt',
#  'stdout-2025-02-06-01-26.txt',
#  'raw_log-2025-02-05-23-30.txt',
#  'args-2025-02-05-18-07.txt',
#  'stdout-2025-02-05-23-30.txt',
#  'stdout-2025-02-05-21-41.txt',
#  'args-2025-02-05-23-30.txt',
#  'stderr-2025-02-05-21-41.txt',
#  'stdout-2025-02-05-18-54.txt',
#  'args-2025-02-06-01-26.txt',
#  'stderr-2025-02-05-18-07.txt',
#  'stderr-2025-02-05-19-42.txt',
#  'raw_log-2025-02-06-01-26.txt',
#  'stderr-2025-02-05-18-54.txt',
#  'stdout-2025-02-06-00-28.txt',
#  'stderr-2025-02-06-01-26.txt',
#  'stderr-2025-02-05-21-01.txt',
#  'raw_log-2025-02-05-18-54.txt',
#  'args-2025-02-05-19-42.txt',
#  'args-2025-02-05-18-54.txt',
#  'raw_log-2025-02-05-21-01.txt',
#  'stdout-2025-02-05-18-07.txt',
#  'raw_log-2025-02-05-21-41.txt',
#  'raw_log-2025-02-06-00-28.txt',
#  'args-2025-02-05-22-12.txt']

# %%
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_lwm, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_lwm, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
import pandas as pd
import numpy as np
from itertools import chain
data_lwm = pd.DataFrame({'Approach': list(chain.from_iterable([['LWM' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
sns.lineplot( data_lwm,  x='Task', y='Average Accuracy')
# Out:
# <Axes: xlabel='Task', ylabel='Average Accuracy'>

# %%
data_lwm.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# LWM      0                95.91                 NaN
#          1                88.91               -2.73
#          2                73.92               23.47
#          3                65.19               32.81

# %%
path_icarl = '/home/karokaro/research-repositories/FACIL/results/pathmnist_icarl_final_pathmnist'

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(path_icarl) if isfile(join(path_icarl, f))]
onlyfiles
# Out:
# ['raw_log-2025-02-05-10-25.txt',
#  'stdout-2025-02-05-10-10.txt',
#  'raw_log-2025-02-05-10-39.txt',
#  'stderr-2025-02-05-09-28.txt',
#  'stderr-2025-02-05-10-39.txt',
#  'stdout-2025-02-05-10-25.txt',
#  'stderr-2025-02-05-08-32.txt',
#  'raw_log-2025-02-05-08-32.txt',
#  'stdout-2025-02-05-08-32.txt',
#  'args-2025-02-05-09-28.txt',
#  'stdout-2025-02-05-10-57.txt',
#  'args-2025-02-05-08-32.txt',
#  'args-2025-02-05-10-25.txt',
#  'stdout-2025-02-05-10-39.txt',
#  'args-2025-02-05-10-39.txt',
#  'stdout-2025-02-05-09-14.txt',
#  'raw_log-2025-02-05-08-43.txt',
#  'args-2025-02-05-10-10.txt',
#  'stdout-2025-02-05-09-28.txt',
#  'args-2025-02-05-09-14.txt',
#  'stdout-2025-02-05-09-00.txt',
#  'args-2025-02-05-09-00.txt',
#  'stderr-2025-02-05-09-14.txt',
#  'stderr-2025-02-05-10-10.txt',
#  'stderr-2025-02-05-10-57.txt',
#  'args-2025-02-05-08-43.txt',
#  'raw_log-2025-02-05-09-28.txt',
#  'args-2025-02-05-10-57.txt',
#  'stderr-2025-02-05-09-00.txt',
#  'raw_log-2025-02-05-09-00.txt',
#  'stdout-2025-02-05-08-43.txt',
#  'raw_log-2025-02-05-10-57.txt',
#  'stderr-2025-02-05-10-25.txt',
#  'raw_log-2025-02-05-10-10.txt',
#  'stderr-2025-02-05-08-43.txt',
#  'raw_log-2025-02-05-09-14.txt']

# %%
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_icarl, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_icarl, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
import pandas as pd
import numpy as np
from itertools import chain
data_icarl = pd.DataFrame({'Approach': list(chain.from_iterable([['iCaRL' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
data_icarl.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# iCaRL    0                95.26                 NaN
#          1                77.21               -1.39
#          2                77.99                0.20
#          3                76.31                4.87

# %%
path_rere = '/home/karokaro/research-repositories/FACIL/results/pathmnist_rere_lrp_final_pathmnist'

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(path_rere) if isfile(join(path_rere, f))]
onlyfiles
# Out:
# ['args-2025-02-05-01-36.txt',
#  'args-2025-02-04-22-26.txt',
#  'stderr-2025-02-05-02-43.txt',
#  'stdout-2025-02-04-20-03.txt',
#  'stderr-2025-02-05-05-32.txt',
#  'args-2025-02-05-03-37.txt',
#  'raw_log-2025-02-05-04-51.txt',
#  'stderr-2025-02-04-21-17.txt',
#  'stderr-2025-02-04-20-03.txt',
#  'stderr-2025-02-05-04-51.txt',
#  'stdout-2025-02-05-04-51.txt',
#  'stdout-2025-02-05-01-36.txt',
#  'args-2025-02-04-21-17.txt',
#  'raw_log-2025-02-05-05-32.txt',
#  'stdout-2025-02-04-23-59.txt',
#  'raw_log-2025-02-04-21-17.txt',
#  'args-2025-02-05-02-43.txt',
#  'raw_log-2025-02-05-01-36.txt',
#  'args-2025-02-04-23-59.txt',
#  'raw_log-2025-02-04-22-26.txt',
#  'raw_log-2025-02-04-23-59.txt',
#  'stderr-2025-02-05-03-37.txt',
#  'raw_log-2025-02-04-20-03.txt',
#  'raw_log-2025-02-05-02-43.txt',
#  'raw_log-2025-02-05-03-37.txt',
#  'args-2025-02-04-20-03.txt',
#  'stdout-2025-02-05-03-37.txt',
#  'stdout-2025-02-05-05-32.txt',
#  'stdout-2025-02-05-02-43.txt',
#  'stdout-2025-02-04-21-17.txt',
#  'stderr-2025-02-04-23-59.txt',
#  'stderr-2025-02-05-01-36.txt',
#  'args-2025-02-05-04-51.txt',
#  'stderr-2025-02-04-22-26.txt',
#  'stdout-2025-02-04-22-26.txt',
#  'args-2025-02-05-05-32.txt']

# %%
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_rere, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_rere, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
data_rere = pd.DataFrame({'Approach': list(chain.from_iterable([['ReReLRP' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
sns.lineplot( data_rere,  x='Task', y='Average Accuracy')
# Out:
# <Axes: xlabel='Task', ylabel='Average Accuracy'>

# %%
data_rere.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# ReReLRP  0                96.42                 NaN
#          1                83.21                8.93
#          2                86.28                4.69
#          3                87.10                3.13

# %%
path_lwm = '/home/karokaro/research-repositories/FACIL/results/pathmnist_joint_finetune_pathmnist'

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(path_lwm) if isfile(join(path_lwm, f))]
onlyfiles
# Out:
# ['raw_log-2025-02-05-21-12.txt',
#  'stderr-2025-02-05-18-55.txt',
#  'stderr-2025-02-06-00-11.txt',
#  'stdout-2025-02-05-22-17.txt',
#  'raw_log-2025-02-05-23-26.txt',
#  'raw_log-2025-02-06-00-59.txt',
#  'raw_log-2025-02-05-19-41.txt',
#  'args-2025-02-05-18-09.txt',
#  'stdout-2025-02-06-00-11.txt',
#  'stdout-2025-02-05-18-55.txt',
#  'raw_log-2025-02-05-20-27.txt',
#  'stdout-2025-02-05-19-41.txt',
#  'raw_log-2025-02-05-18-09.txt',
#  'raw_log-2025-02-05-22-17.txt',
#  'stdout-2025-02-06-00-59.txt',
#  'stderr-2025-02-05-19-41.txt',
#  'args-2025-02-05-19-41.txt',
#  'args-2025-02-05-18-55.txt',
#  'args-2025-02-05-21-12.txt',
#  'stderr-2025-02-05-22-17.txt',
#  'args-2025-02-06-00-59.txt',
#  'stdout-2025-02-05-18-09.txt',
#  'args-2025-02-05-23-26.txt',
#  'args-2025-02-05-20-27.txt',
#  'args-2025-02-06-00-11.txt',
#  'stdout-2025-02-05-23-26.txt',
#  'stderr-2025-02-05-18-09.txt',
#  'stderr-2025-02-05-20-27.txt',
#  'raw_log-2025-02-06-00-11.txt',
#  'stderr-2025-02-05-23-26.txt',
#  'stderr-2025-02-05-21-12.txt',
#  'raw_log-2025-02-05-18-55.txt',
#  'stdout-2025-02-05-20-27.txt',
#  'stdout-2025-02-05-21-12.txt',
#  'args-2025-02-05-22-17.txt',
#  'stderr-2025-02-06-00-59.txt']

# %%
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_lwm, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_lwm, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
res_dict
# Out:
# {'2025-02-05-21-12.txt': [{'group': 'valid',
#    'iter': 1,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 1.1031641180635967},
#   {'group': 'valid',
#    'iter': 1,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 30.02735978112175},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 1.0428226416479547},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 48.93980848153215},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 1.0077231959344262},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 79.89056087551299},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 1.0953907738305964},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 26.915184678522575},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 4},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 1.1213557343476448},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 32.523939808481536},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 3},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 1.1341943153767513},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 32.523939808481536},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 2},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 7,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 1.0865644531276093},
#   {'group': 'valid',
#    'iter': 7,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 35.43091655266758},
#   {'group': 'train',
#    'iter': 7,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 1},
#   {'group': 'train',
#    'iter': 7,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.05},
#   {'group': 'valid',
#    'iter': 8,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 1.1245278692441176},
#   {'group': 'valid',
#    'iter': 8,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 32.523939808481536},
#   {'group': 'train',
#    'iter': 8,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 8,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 9,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.932305192001541},
#   {'group': 'valid',
#    'iter': 9,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 68.36525307797537},
#   {'group': 'train',
#    'iter': 9,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 9,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 10,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.8897298801940051},
#   {'group': 'valid',
#    'iter': 10,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 81.01915184678523},
#   {'group': 'train',
#    'iter': 10,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 10,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 11,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.8065438198814966},
#   {'group': 'valid',
#    'iter': 11,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 82.42134062927497},
#   {'group': 'train',
#    'iter': 11,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 5},
#   {'group': 'train',
#    'iter': 11,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-13',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 12,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.8734815431358713},
#   {'group': 'valid',
#    'iter': 12,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 77.35978112175103},
#   {'group': 'train',
#    'iter': 12,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 4},
#   {'group': 'train',
#    'iter': 12,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 13,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.707688215411639},
#   {'group': 'valid',
#    'iter': 13,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 80.43775649794802},
#   {'group': 'train',
#    'iter': 13,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 5},
#   {'group': 'train',
#    'iter': 13,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 14,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.8415350367693503},
#   {'group': 'valid',
#    'iter': 14,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 73.70041039671683},
#   {'group': 'train',
#    'iter': 14,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 4},
#   {'group': 'train',
#    'iter': 14,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 15,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.6564915273975576},
#   {'group': 'valid',
#    'iter': 15,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 77.32558139534885},
#   {'group': 'train',
#    'iter': 15,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 5},
#   {'group': 'train',
#    'iter': 15,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 16,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.5651037846927603},
#   {'group': 'valid',
#    'iter': 16,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 83.75512995896032},
#   {'group': 'train',
#    'iter': 16,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 5},
#   {'group': 'train',
#    'iter': 16,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 17,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.523983308456828},
#   {'group': 'valid',
#    'iter': 17,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 81.42954856361149},
#   {'group': 'train',
#    'iter': 17,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 5},
#   {'group': 'train',
#    'iter': 17,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 18,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.5265207764184263},
#   {'group': 'valid',
#    'iter': 18,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 82.86593707250341},
#   {'group': 'train',
#    'iter': 18,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 4},
#   {'group': 'train',
#    'iter': 18,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.4265009953695185},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 82.79753761969904},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 5},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.433072967095512},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 87.72229822161422},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 4},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.7216895262617745},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 66.24487004103968},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 3},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.4995589320294345},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 83.44733242134062},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 2},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-14',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.36019498060894406},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 86.32010943912448},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.6551728403519345},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 78.07797537619699},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 4},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.3265981606109687},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 87.82489740082079},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.3529083878209588},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 87.20930232558139},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 4},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.5892698723165428},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 82.72913816689467},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 3},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.40175583754779537},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 84.19972640218877},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 2},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.5680865705441352},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 76.5731874145007},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 1},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.016666666666666666},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.38168297489919023},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 86.04651162790698},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.2982533460154253},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 88.33789329685362},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.27435502344704193},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 89.12448700410397},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 5},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.2958419834621628},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 89.05608755129958},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 4},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-15',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.2643632435643722},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 89.39808481532148},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.25202141991636823},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 89.53488372093024},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.3015546706567548},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 86.93570451436389},
#   {'group': 'train',
#    'iter': 36,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 4},
#   {'group': 'train',
#    'iter': 36,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 37,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.24601609397440047},
#   {'group': 'valid',
#    'iter': 37,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 89.6374829001368},
#   {'group': 'train',
#    'iter': 37,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 37,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 38,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.24248426969172038},
#   {'group': 'valid',
#    'iter': 38,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 89.43228454172366},
#   {'group': 'train',
#    'iter': 38,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 38,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 39,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.23817419437067291},
#   {'group': 'valid',
#    'iter': 39,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 89.6374829001368},
#   {'group': 'train',
#    'iter': 39,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 39,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 40,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.264689082496388},
#   {'group': 'valid',
#    'iter': 40,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 93.63885088919288},
#   {'group': 'train',
#    'iter': 40,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 4},
#   {'group': 'train',
#    'iter': 40,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 41,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.22333978071666122},
#   {'group': 'valid',
#    'iter': 41,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 89.97948016415869},
#   {'group': 'train',
#    'iter': 41,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 5},
#   {'group': 'train',
#    'iter': 41,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 42,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.2276118658432067},
#   {'group': 'valid',
#    'iter': 42,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 93.6046511627907},
#   {'group': 'train',
#    'iter': 42,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 4},
#   {'group': 'train',
#    'iter': 42,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 43,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.43390613435557374},
#   {'group': 'valid',
#    'iter': 43,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 83.5499316005472},
#   {'group': 'train',
#    'iter': 43,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 3},
#   {'group': 'train',
#    'iter': 43,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-16',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 44,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.22462576990577657},
#   {'group': 'valid',
#    'iter': 44,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 89.67168262653898},
#   {'group': 'train',
#    'iter': 44,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 2},
#   {'group': 'train',
#    'iter': 44,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 45,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.22380091748346873},
#   {'group': 'valid',
#    'iter': 45,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 89.87688098495212},
#   {'group': 'train',
#    'iter': 45,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 1},
#   {'group': 'train',
#    'iter': 45,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 46,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.21076660295476993},
#   {'group': 'valid',
#    'iter': 46,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 94.52804377564979},
#   {'group': 'train',
#    'iter': 46,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 5},
#   {'group': 'train',
#    'iter': 46,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 47,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.21726240616205128},
#   {'group': 'valid',
#    'iter': 47,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 89.87688098495212},
#   {'group': 'train',
#    'iter': 47,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 4},
#   {'group': 'train',
#    'iter': 47,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 48,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.22521070055612624},
#   {'group': 'valid',
#    'iter': 48,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 94.11764705882352},
#   {'group': 'train',
#    'iter': 48,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 3},
#   {'group': 'train',
#    'iter': 48,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 49,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.20260647015719993},
#   {'group': 'valid',
#    'iter': 49,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 92.9890560875513},
#   {'group': 'train',
#    'iter': 49,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 5},
#   {'group': 'train',
#    'iter': 49,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 50,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.2424337628989311},
#   {'group': 'valid',
#    'iter': 50,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 89.87688098495212},
#   {'group': 'train',
#    'iter': 50,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 4},
#   {'group': 'train',
#    'iter': 50,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 51,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.20545189097910996},
#   {'group': 'valid',
#    'iter': 51,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 91.82626538987688},
#   {'group': 'train',
#    'iter': 51,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 3},
#   {'group': 'train',
#    'iter': 51,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 52,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.23586020885206116},
#   {'group': 'valid',
#    'iter': 52,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 94.25444596443229},
#   {'group': 'train',
#    'iter': 52,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 2},
#   {'group': 'train',
#    'iter': 52,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 53,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.20377477871001826},
#   {'group': 'valid',
#    'iter': 53,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 94.25444596443229},
#   {'group': 'train',
#    'iter': 53,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 1},
#   {'group': 'train',
#    'iter': 53,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 54,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.18969990900130343},
#   {'group': 'valid',
#    'iter': 54,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 95.00683994528045},
#   {'group': 'train',
#    'iter': 54,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 5},
#   {'group': 'train',
#    'iter': 54,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-17',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 55,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.5187040933098251},
#   {'group': 'valid',
#    'iter': 55,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 79.20656634746922},
#   {'group': 'train',
#    'iter': 55,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 4},
#   {'group': 'train',
#    'iter': 55,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 56,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.3776698243968627},
#   {'group': 'valid',
#    'iter': 56,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 84.37072503419972},
#   {'group': 'train',
#    'iter': 56,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 3},
#   {'group': 'train',
#    'iter': 56,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 57,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.29782490542339396},
#   {'group': 'valid',
#    'iter': 57,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 88.98768809849521},
#   {'group': 'train',
#    'iter': 57,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 2},
#   {'group': 'train',
#    'iter': 57,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 58,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.3004867669944072},
#   {'group': 'valid',
#    'iter': 58,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 88.95348837209302},
#   {'group': 'train',
#    'iter': 58,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 1},
#   {'group': 'train',
#    'iter': 58,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 59,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.26083731533075327},
#   {'group': 'valid',
#    'iter': 59,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 89.46648426812585},
#   {'group': 'train',
#    'iter': 59,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 5},
#   {'group': 'train',
#    'iter': 59,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 60,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.18726809188295487},
#   {'group': 'valid',
#    'iter': 60,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 94.32284541723666},
#   {'group': 'train',
#    'iter': 60,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 5},
#   {'group': 'train',
#    'iter': 60,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 61,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.18807738133681945},
#   {'group': 'valid',
#    'iter': 61,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 93.84404924760602},
#   {'group': 'train',
#    'iter': 61,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 4},
#   {'group': 'train',
#    'iter': 61,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 62,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.18233664895416773},
#   {'group': 'valid',
#    'iter': 62,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 94.87004103967168},
#   {'group': 'train',
#    'iter': 62,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 5},
#   {'group': 'train',
#    'iter': 62,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 63,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.17938243342938076},
#   {'group': 'valid',
#    'iter': 63,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 95.10943912448701},
#   {'group': 'train',
#    'iter': 63,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 5},
#   {'group': 'train',
#    'iter': 63,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 64,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.17981734474364122},
#   {'group': 'valid',
#    'iter': 64,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 95.34883720930233},
#   {'group': 'train',
#    'iter': 64,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 4},
#   {'group': 'train',
#    'iter': 64,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 65,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.1715047815062931},
#   {'group': 'valid',
#    'iter': 65,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 95.38303693570451},
#   {'group': 'train',
#    'iter': 65,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 5},
#   {'group': 'train',
#    'iter': 65,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-18',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 66,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.16621460212157624},
#   {'group': 'valid',
#    'iter': 66,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 95.55403556771546},
#   {'group': 'train',
#    'iter': 66,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 5},
#   {'group': 'train',
#    'iter': 66,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 67,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.17767647344991055},
#   {'group': 'valid',
#    'iter': 67,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 94.56224350205198},
#   {'group': 'train',
#    'iter': 67,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 4},
#   {'group': 'train',
#    'iter': 67,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 68,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.20654412528191643},
#   {'group': 'valid',
#    'iter': 68,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 92.03146374829001},
#   {'group': 'train',
#    'iter': 68,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 3},
#   {'group': 'train',
#    'iter': 68,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 69,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.1710338946202548},
#   {'group': 'valid',
#    'iter': 69,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 94.93844049247606},
#   {'group': 'train',
#    'iter': 69,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 2},
#   {'group': 'train',
#    'iter': 69,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 70,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.16123785662545062},
#   {'group': 'valid',
#    'iter': 70,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 95.7250341997264},
#   {'group': 'train',
#    'iter': 70,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 5},
#   {'group': 'train',
#    'iter': 70,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 71,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.16278087032803432},
#   {'group': 'valid',
#    'iter': 71,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 95.65663474692202},
#   {'group': 'train',
#    'iter': 71,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 4},
#   {'group': 'train',
#    'iter': 71,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 72,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.16589296187201538},
#   {'group': 'valid',
#    'iter': 72,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 95.4514363885089},
#   {'group': 'train',
#    'iter': 72,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 3},
#   {'group': 'train',
#    'iter': 72,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 73,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.1574899710093086},
#   {'group': 'valid',
#    'iter': 73,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 95.4514363885089},
#   {'group': 'train',
#    'iter': 73,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 5},
#   {'group': 'train',
#    'iter': 73,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 74,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.16424557048873276},
#   {'group': 'valid',
#    'iter': 74,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 95.4514363885089},
#   {'group': 'train',
#    'iter': 74,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 4},
#   {'group': 'train',
#    'iter': 74,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 75,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.1593167720064419},
#   {'group': 'valid',
#    'iter': 75,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 95.48563611491107},
#   {'group': 'train',
#    'iter': 75,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 3},
#   {'group': 'train',
#    'iter': 75,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 76,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.1606193245598784},
#   {'group': 'valid',
#    'iter': 76,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 95.62243502051983},
#   {'group': 'train',
#    'iter': 76,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 2},
#   {'group': 'train',
#    'iter': 76,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-19',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 77,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.1544908246614049},
#   {'group': 'valid',
#    'iter': 77,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 95.55403556771546},
#   {'group': 'train',
#    'iter': 77,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 77,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 78,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.18163810845683603},
#   {'group': 'valid',
#    'iter': 78,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 93.94664842681259},
#   {'group': 'train',
#    'iter': 78,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 78,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 79,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.22104690555692044},
#   {'group': 'valid',
#    'iter': 79,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 91.14227086183311},
#   {'group': 'train',
#    'iter': 79,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 3},
#   {'group': 'train',
#    'iter': 79,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 80,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.15876607124970157},
#   {'group': 'valid',
#    'iter': 80,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 95.58823529411765},
#   {'group': 'train',
#    'iter': 80,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 2},
#   {'group': 'train',
#    'iter': 80,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 81,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.15673392075438833},
#   {'group': 'valid',
#    'iter': 81,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 95.58823529411765},
#   {'group': 'train',
#    'iter': 81,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 1},
#   {'group': 'train',
#    'iter': 81,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 82,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.17023744202243157},
#   {'group': 'valid',
#    'iter': 82,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 94.39124487004104},
#   {'group': 'train',
#    'iter': 82,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 82,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 83,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.15412746406531042},
#   {'group': 'valid',
#    'iter': 83,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 95.69083447332422},
#   {'group': 'train',
#    'iter': 83,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 83,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 84,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.16180837221657693},
#   {'group': 'valid',
#    'iter': 84,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 95.55403556771546},
#   {'group': 'train',
#    'iter': 84,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 84,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 85,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.15168596061122402},
#   {'group': 'valid',
#    'iter': 85,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 95.62243502051983},
#   {'group': 'train',
#    'iter': 85,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 85,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 86,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.1524487470675428},
#   {'group': 'valid',
#    'iter': 86,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 95.58823529411765},
#   {'group': 'train',
#    'iter': 86,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 86,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 87,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.1496502572897358},
#   {'group': 'valid',
#    'iter': 87,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 95.7250341997264},
#   {'group': 'train',
#    'iter': 87,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 87,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-20',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 88,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 0.15211413982139566},
#   {'group': 'valid',
#    'iter': 88,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 95.7250341997264},
#   {'group': 'train',
#    'iter': 88,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 88,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 89,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 0.15469192637056725},
#   {'group': 'valid',
#    'iter': 89,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 95.7592339261286},
#   {'group': 'train',
#    'iter': 89,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 3},
#   {'group': 'train',
#    'iter': 89,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 90,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 0.15236355664995888},
#   {'group': 'valid',
#    'iter': 90,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 95.82763337893296},
#   {'group': 'train',
#    'iter': 90,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 2},
#   {'group': 'train',
#    'iter': 90,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 91,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 0.1672925235940559},
#   {'group': 'valid',
#    'iter': 91,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 95.24623803009577},
#   {'group': 'train',
#    'iter': 91,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 1},
#   {'group': 'train',
#    'iter': 91,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 0.0006172839506172839},
#   {'group': 'valid',
#    'iter': 92,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 0.15138308066879838},
#   {'group': 'valid',
#    'iter': 92,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 95.65663474692202},
#   {'group': 'train',
#    'iter': 92,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 92,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 0.00020576131687242798},
#   {'group': 'valid',
#    'iter': 93,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 0.1511902601933349},
#   {'group': 'valid',
#    'iter': 93,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 95.7250341997264},
#   {'group': 'train',
#    'iter': 93,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-21-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 93,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-21-21',
# ...
#    'task': 2,
#    'time': '2025-02-05-19-23',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 15,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-23',
#    'value': 1},
#   {'group': 'train',
#    'iter': 15,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-23',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 16,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 16,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 16,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 5},
#   {'group': 'train',
#    'iter': 16,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 17,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 17,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 17,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 4},
#   {'group': 'train',
#    'iter': 17,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 18,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 18,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 18,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 3},
#   {'group': 'train',
#    'iter': 18,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-24',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 2},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 1},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 5},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 4},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-25',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 3},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 2},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 1},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 5},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-26',
#    'value': 0.00041152263374485596},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 4},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 0.00041152263374485596},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 3},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 0.00041152263374485596},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 2},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 0.00041152263374485596},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 1},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-27',
#    'value': 0.00041152263374485596},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 5},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 0.00013717421124828533},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 4},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 0.00013717421124828533},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 3},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-28',
#    'value': 0.00013717421124828533},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 2},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 0.00013717421124828533},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 40.84465445953928},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'patience',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 1},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'lr',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 0.00013717421124828533},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 2.1380904178632176e+20},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'acc',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 40.84465445953928},
#   {'group': 'test',
#    'iter': 0,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 1.6645841149661757e+20},
#   {'group': 'test',
#    'iter': 0,
#    'name': 'acc_taw',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 53.01109350237718},
#   {'group': 'test',
#    'iter': 0,
#    'name': 'acc_tag',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 53.01109350237718},
#   {'group': 'test',
#    'iter': 0,
#    'name': 'forg_taw',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 45.00792393026941},
#   {'group': 'test',
#    'iter': 0,
#    'name': 'forg_tag',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 45.00792393026941},
#   {'group': 'test',
#    'iter': 1,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 4.707448717666427e+19},
#   {'group': 'test',
#    'iter': 1,
#    'name': 'acc_taw',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 37.98681845416417},
#   {'group': 'test',
#    'iter': 1,
#    'name': 'acc_tag',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 0.0},
#   {'group': 'test',
#    'iter': 1,
#    'name': 'forg_taw',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 0.0},
#   {'group': 'test',
#    'iter': 1,
#    'name': 'forg_tag',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 0.0},
#   {'group': 'test',
#    'iter': 2,
#    'name': 'loss',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 2.148981757486514e+20},
#   {'group': 'test',
#    'iter': 2,
#    'name': 'acc_taw',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 55.58889722430608},
#   {'group': 'test',
#    'iter': 2,
#    'name': 'acc_tag',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 0.0},
#   {'group': 'test',
#    'iter': 2,
#    'name': 'forg_taw',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 0.0},
#   {'group': 'test',
#    'iter': 2,
#    'name': 'forg_tag',
#    'task': 2,
#    'time': '2025-02-05-19-29',
#    'value': 0.0},
#   {'group': 'valid',
#    'iter': 1,
#    'name': 'loss',
#    'task': 3,
#    'time': '2025-02-05-19-29',
#    'value': 2.1324884624852386e+20},
#   {'group': 'valid',
#    'iter': 1,
#    'name': 'acc',
#    'task': 3,
#    'time': '2025-02-05-19-29',
#    'value': 45.044444444444444},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'patience',
#    'task': 3,
#    'time': '2025-02-05-19-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'lr',
#    'task': 3,
#    'time': '2025-02-05-19-29',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'loss',
#    'task': 3,
#    'time': '2025-02-05-19-30',
#    'value': 2.1324884624852386e+20},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'acc',
#    'task': 3,
#    'time': '2025-02-05-19-30',
#    'value': 45.044444444444444},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'patience',
#    'task': 3,
#    'time': '2025-02-05-19-30',
#    'value': 4},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'lr',
#    'task': 3,
#    'time': '2025-02-05-19-30',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'loss',
#    'task': 3,
#    'time': '2025-02-05-19-30',
#    'value': 2.1324884624852386e+20},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'acc',
#    'task': 3,
#    'time': '2025-02-05-19-30',
#    'value': 45.044444444444444},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'patience',
#    'task': 3,
#    'time': '2025-02-05-19-30',
#    'value': 3},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'lr',
#    'task': 3,
#    'time': '2025-02-05-19-30',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'loss',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 2.1324884624852386e+20},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'acc',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 45.044444444444444},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'patience',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 2},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'lr',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'loss',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 2.1324884624852386e+20},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'acc',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 45.044444444444444},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'patience',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 1},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'lr',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'loss',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 2.1324884624852386e+20},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'acc',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 45.044444444444444},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'patience',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 5},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'lr',
#    'task': 3,
#    'time': '2025-02-05-19-31',
#    'value': 0.03333333333333333},
#   ...]}

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
import pandas as pd
import numpy as np
from itertools import chain
data_joint = pd.DataFrame({'Approach': list(chain.from_iterable([['Joint' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
sns.lineplot( data_joint,  x='Task', y='Average Accuracy', ci=None)
# Out:
# /tmp/ipykernel_16290/2585113533.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot( data_joint,  x='Task', y='Average Accuracy', ci=None)
# <Axes: xlabel='Task', ylabel='Average Accuracy'>

# %%
data_joint.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# Joint    0                97.52                 NaN
#          1                94.77                1.14
#          2                88.88                6.20
#          3                94.56               -2.08

# %%
data_all = pd.concat([data, data_ewc, data_icarl, data_rere, data_joint, data_lwm], ignore_index=True)

# %%
import matplotlib.pyplot as plt
hue_order = ["LWM", "LWF", "EWC", "iCaRL", "ReReLRP", "Joint"]
paletter = sns.color_palette("colorblind", 6)
sns.set_theme(style="ticks", font_scale=1.3) 
g = sns.lineplot( data_all, hue='Approach', x='Task', y='Average Accuracy', hue_order=hue_order, ci=None)
g.set_xticks(range(4))
g.set_xticklabels([i+1 for i in range(4)])
import matplotlib.ticker as mtick
g.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))
plt.savefig("pathmnist_taw.pdf", format='pdf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_16290/4182661404.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   g = sns.lineplot( data_all, hue='Approach', x='Task', y='Average Accuracy', hue_order=hue_order, ci=None)
