# %%
path_lwf = '/home/karokaro/research-repositories/FACIL/results/bloodmnist_lwf_final_bloodmnist'

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(path_lwf) if isfile(join(path_lwf, f))]
onlyfiles
# Out:
# ['raw_log-2025-02-03-23-03.txt',
#  'raw_log-2025-02-03-23-25.txt',
#  'stderr-2025-02-04-00-24.txt',
#  'raw_log-2025-02-03-23-51.txt',
#  'stdout-2025-02-03-23-36.txt',
#  'stdout-2025-02-04-00-24.txt',
#  'raw_log-2025-02-04-00-17.txt',
#  'args-2025-02-03-23-51.txt',
#  'stderr-2025-02-04-00-17.txt',
#  'stderr-2025-02-03-23-25.txt',
#  'stderr-2025-02-04-00-09.txt',
#  'stdout-2025-02-03-23-16.txt',
#  'raw_log-2025-02-03-23-36.txt',
#  'args-2025-02-04-00-24.txt',
#  'stdout-2025-02-03-23-59.txt',
#  'stderr-2025-02-03-23-36.txt',
#  'raw_log-2025-02-04-00-09.txt',
#  'args-2025-02-03-23-59.txt',
#  'raw_log-2025-02-03-23-16.txt',
#  'stdout-2025-02-04-00-17.txt',
#  'args-2025-02-03-23-25.txt',
#  'args-2025-02-03-23-36.txt',
#  'stderr-2025-02-03-23-16.txt',
#  'args-2025-02-03-23-16.txt',
#  'stderr-2025-02-03-23-51.txt',
#  'stdout-2025-02-04-00-09.txt',
#  'raw_log-2025-02-03-23-59.txt',
#  'args-2025-02-04-00-17.txt',
#  'stdout-2025-02-03-23-03.txt',
#  'stderr-2025-02-03-23-03.txt',
#  'stderr-2025-02-03-23-59.txt',
#  'stdout-2025-02-03-23-51.txt',
#  'args-2025-02-04-00-09.txt',
#  'stdout-2025-02-03-23-25.txt',
#  'raw_log-2025-02-04-00-24.txt',
#  'args-2025-02-03-23-03.txt']

# %%
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_lwf, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_lwf, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
res_dict
# Out:
# {'2025-02-03-23-03.txt': [{'group': 'valid',
#    'iter': 1,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 0.5982394814491272},
#   {'group': 'valid',
#    'iter': 1,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 5},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 0.6027634143829346},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 4},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 0.5964184999465942},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 5},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 0.5960327982902527},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 5},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 0.62259840965271},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 4},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-03',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5832515358924866},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 7,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.6067276000976562},
#   {'group': 'valid',
#    'iter': 7,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 7,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 4},
#   {'group': 'train',
#    'iter': 7,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 8,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.583138108253479},
#   {'group': 'valid',
#    'iter': 8,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 8,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 8,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 9,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.581243634223938},
#   {'group': 'valid',
#    'iter': 9,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 9,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 9,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 10,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5824303030967712},
#   {'group': 'valid',
#    'iter': 10,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 10,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 4},
#   {'group': 'train',
#    'iter': 10,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 11,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5640628337860107},
#   {'group': 'valid',
#    'iter': 11,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 11,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 11,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 12,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5961509346961975},
#   {'group': 'valid',
#    'iter': 12,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 12,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 4},
#   {'group': 'train',
#    'iter': 12,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 13,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5695979595184326},
#   {'group': 'valid',
#    'iter': 13,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 13,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 3},
#   {'group': 'train',
#    'iter': 13,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 14,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5813966989517212},
#   {'group': 'valid',
#    'iter': 14,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 14,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 2},
#   {'group': 'train',
#    'iter': 14,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 15,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5558269023895264},
#   {'group': 'valid',
#    'iter': 15,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 15,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 15,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 16,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5333248972892761},
#   {'group': 'valid',
#    'iter': 16,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 16,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 16,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 17,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.6433296203613281},
#   {'group': 'valid',
#    'iter': 17,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 17,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 4},
#   {'group': 'train',
#    'iter': 17,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 18,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5912613272666931},
#   {'group': 'valid',
#    'iter': 18,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 18,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 3},
#   {'group': 'train',
#    'iter': 18,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5843906998634338},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 2},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5770521759986877},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 1},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.1},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5654615759849548},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5196952223777771},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5307166576385498},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 4},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5071393847465515},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5438422560691833},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 4},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.4748440980911255},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5124030709266663},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 4},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.46900275349617004},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5331726670265198},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 4},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5716662406921387},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 3},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5049455165863037},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 2},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.4622175693511963},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.42840102314949036},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.608778178691864},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 4},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.47605574131011963},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 3},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.45888546109199524},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 36,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 2},
#   {'group': 'train',
#    'iter': 36,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 37,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.5554490089416504},
#   {'group': 'valid',
#    'iter': 37,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 37,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 1},
#   {'group': 'train',
#    'iter': 37,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.03333333333333333},
#   {'group': 'valid',
#    'iter': 38,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.4802685081958771},
#   {'group': 'valid',
#    'iter': 38,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 38,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 38,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 39,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.3929973542690277},
#   {'group': 'valid',
#    'iter': 39,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 39,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 39,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 40,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.3796902894973755},
#   {'group': 'valid',
#    'iter': 40,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 40,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 40,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 41,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.382649689912796},
#   {'group': 'valid',
#    'iter': 41,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 41,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 4},
#   {'group': 'train',
#    'iter': 41,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 42,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.3532048165798187},
#   {'group': 'valid',
#    'iter': 42,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 42,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 5},
#   {'group': 'train',
#    'iter': 42,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-04',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 43,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.3700938820838928},
#   {'group': 'valid',
#    'iter': 43,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 43,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 4},
#   {'group': 'train',
#    'iter': 43,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 44,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.36353394389152527},
#   {'group': 'valid',
#    'iter': 44,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 88.44884488448845},
#   {'group': 'train',
#    'iter': 44,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 3},
#   {'group': 'train',
#    'iter': 44,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 45,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.34488725662231445},
#   {'group': 'valid',
#    'iter': 45,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 91.41914191419141},
#   {'group': 'train',
#    'iter': 45,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 45,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 46,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.3593405783176422},
#   {'group': 'valid',
#    'iter': 46,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 96.36963696369637},
#   {'group': 'train',
#    'iter': 46,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 4},
#   {'group': 'train',
#    'iter': 46,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 47,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.37241142988204956},
#   {'group': 'valid',
#    'iter': 47,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 99.00990099009901},
#   {'group': 'train',
#    'iter': 47,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 3},
#   {'group': 'train',
#    'iter': 47,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 48,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.30771303176879883},
#   {'group': 'valid',
#    'iter': 48,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 91.74917491749174},
#   {'group': 'train',
#    'iter': 48,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 48,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 49,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.28933295607566833},
#   {'group': 'valid',
#    'iter': 49,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 86.79867986798679},
#   {'group': 'train',
#    'iter': 49,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 49,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 50,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.29323846101760864},
#   {'group': 'valid',
#    'iter': 50,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 97.35973597359737},
#   {'group': 'train',
#    'iter': 50,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 4},
#   {'group': 'train',
#    'iter': 50,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 51,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.3403542935848236},
#   {'group': 'valid',
#    'iter': 51,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 99.00990099009901},
#   {'group': 'train',
#    'iter': 51,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 3},
#   {'group': 'train',
#    'iter': 51,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 52,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.3845894932746887},
#   {'group': 'valid',
#    'iter': 52,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 96.69966996699671},
#   {'group': 'train',
#    'iter': 52,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 2},
#   {'group': 'train',
#    'iter': 52,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 53,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.2705257534980774},
#   {'group': 'valid',
#    'iter': 53,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 97.35973597359737},
#   {'group': 'train',
#    'iter': 53,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 53,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 54,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.6717759966850281},
#   {'group': 'valid',
#    'iter': 54,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 50.165016501650165},
#   {'group': 'train',
#    'iter': 54,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 4},
#   {'group': 'train',
#    'iter': 54,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 55,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.3236408531665802},
#   {'group': 'valid',
#    'iter': 55,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 76.89768976897689},
#   {'group': 'train',
#    'iter': 55,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 3},
#   {'group': 'train',
#    'iter': 55,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 56,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.38341471552848816},
#   {'group': 'valid',
#    'iter': 56,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 73.26732673267327},
#   {'group': 'train',
#    'iter': 56,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 2},
#   {'group': 'train',
#    'iter': 56,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 57,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.37959301471710205},
#   {'group': 'valid',
#    'iter': 57,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 73.26732673267327},
#   {'group': 'train',
#    'iter': 57,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 1},
#   {'group': 'train',
#    'iter': 57,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.011111111111111112},
#   {'group': 'valid',
#    'iter': 58,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.3696141839027405},
#   {'group': 'valid',
#    'iter': 58,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 73.92739273927393},
#   {'group': 'train',
#    'iter': 58,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 58,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 59,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.25382477045059204},
#   {'group': 'valid',
#    'iter': 59,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 93.72937293729373},
#   {'group': 'train',
#    'iter': 59,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 59,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 60,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.2514785826206207},
#   {'group': 'valid',
#    'iter': 60,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 94.71947194719472},
#   {'group': 'train',
#    'iter': 60,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 60,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 61,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.24525423347949982},
#   {'group': 'valid',
#    'iter': 61,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 93.72937293729373},
#   {'group': 'train',
#    'iter': 61,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 61,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 62,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.24171631038188934},
#   {'group': 'valid',
#    'iter': 62,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 93.3993399339934},
#   {'group': 'train',
#    'iter': 62,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 62,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 63,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.23683317005634308},
#   {'group': 'valid',
#    'iter': 63,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 95.04950495049505},
#   {'group': 'train',
#    'iter': 63,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 63,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 64,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.23359936475753784},
#   {'group': 'valid',
#    'iter': 64,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 97.02970297029702},
#   {'group': 'train',
#    'iter': 64,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 64,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 65,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.2308838665485382},
#   {'group': 'valid',
#    'iter': 65,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 92.73927392739274},
#   {'group': 'train',
#    'iter': 65,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 65,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 66,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.22752946615219116},
#   {'group': 'valid',
#    'iter': 66,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 98.34983498349835},
#   {'group': 'train',
#    'iter': 66,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 66,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 67,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.22073213756084442},
#   {'group': 'valid',
#    'iter': 67,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 95.7095709570957},
#   {'group': 'train',
#    'iter': 67,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 67,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 68,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.21731151640415192},
#   {'group': 'valid',
#    'iter': 68,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 93.72937293729373},
#   {'group': 'train',
#    'iter': 68,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 68,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 69,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.2144697606563568},
#   {'group': 'valid',
#    'iter': 69,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 93.3993399339934},
#   {'group': 'train',
#    'iter': 69,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 69,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 70,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.21777565777301788},
#   {'group': 'valid',
#    'iter': 70,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 98.67986798679867},
#   {'group': 'train',
#    'iter': 70,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 4},
#   {'group': 'train',
#    'iter': 70,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 71,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.20084036886692047},
#   {'group': 'valid',
#    'iter': 71,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 95.37953795379538},
#   {'group': 'train',
#    'iter': 71,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 71,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 72,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.19647668302059174},
#   {'group': 'valid',
#    'iter': 72,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 96.03960396039604},
#   {'group': 'train',
#    'iter': 72,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 72,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 73,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.19289980828762054},
#   {'group': 'valid',
#    'iter': 73,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 98.34983498349835},
#   {'group': 'train',
#    'iter': 73,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 73,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 74,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.1886323243379593},
#   {'group': 'valid',
#    'iter': 74,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 97.02970297029702},
#   {'group': 'train',
#    'iter': 74,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 74,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 75,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.18164287507534027},
#   {'group': 'valid',
#    'iter': 75,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 98.34983498349835},
#   {'group': 'train',
#    'iter': 75,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 75,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 76,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.20387227833271027},
#   {'group': 'valid',
#    'iter': 76,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 99.00990099009901},
#   {'group': 'train',
#    'iter': 76,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 4},
#   {'group': 'train',
#    'iter': 76,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 77,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.19670940935611725},
#   {'group': 'valid',
#    'iter': 77,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 99.00990099009901},
#   {'group': 'train',
#    'iter': 77,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 3},
#   {'group': 'train',
#    'iter': 77,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 78,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.2020910233259201},
#   {'group': 'valid',
#    'iter': 78,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 98.67986798679867},
#   {'group': 'train',
#    'iter': 78,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 2},
#   {'group': 'train',
#    'iter': 78,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 79,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.1955973505973816},
#   {'group': 'valid',
#    'iter': 79,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 98.67986798679867},
#   {'group': 'train',
#    'iter': 79,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 1},
#   {'group': 'train',
#    'iter': 79,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 80,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.16573069989681244},
#   {'group': 'valid',
#    'iter': 80,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 95.7095709570957},
#   {'group': 'train',
#    'iter': 80,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 80,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 81,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.16952773928642273},
#   {'group': 'valid',
#    'iter': 81,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 99.00990099009901},
#   {'group': 'train',
#    'iter': 81,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 4},
#   {'group': 'train',
#    'iter': 81,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 82,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.17797118425369263},
#   {'group': 'valid',
#    'iter': 82,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 93.3993399339934},
#   {'group': 'train',
#    'iter': 82,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 3},
#   {'group': 'train',
#    'iter': 82,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 83,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.2538875341415405},
#   {'group': 'valid',
#    'iter': 83,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 86.46864686468648},
#   {'group': 'train',
#    'iter': 83,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 2},
#   {'group': 'train',
#    'iter': 83,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 84,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.16400288045406342},
#   {'group': 'valid',
#    'iter': 84,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 94.05940594059405},
#   {'group': 'train',
#    'iter': 84,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 5},
#   {'group': 'train',
#    'iter': 84,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-05',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 85,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.1478136032819748},
#   {'group': 'valid',
#    'iter': 85,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 98.34983498349835},
#   {'group': 'train',
#    'iter': 85,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 5},
#   {'group': 'train',
#    'iter': 85,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 86,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.1397116333246231},
#   {'group': 'valid',
#    'iter': 86,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 99.00990099009901},
#   {'group': 'train',
#    'iter': 86,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 5},
#   {'group': 'train',
#    'iter': 86,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 87,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.16906078159809113},
#   {'group': 'valid',
#    'iter': 87,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 93.3993399339934},
#   {'group': 'train',
#    'iter': 87,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 4},
#   {'group': 'train',
#    'iter': 87,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 88,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.20091843605041504},
#   {'group': 'valid',
#    'iter': 88,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 90.0990099009901},
#   {'group': 'train',
#    'iter': 88,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 3},
#   {'group': 'train',
#    'iter': 88,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 89,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.24325133860111237},
#   {'group': 'valid',
#    'iter': 89,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 87.78877887788778},
#   {'group': 'train',
#    'iter': 89,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 2},
#   {'group': 'train',
#    'iter': 89,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 90,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.17319832742214203},
#   {'group': 'valid',
#    'iter': 90,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 93.3993399339934},
#   {'group': 'train',
#    'iter': 90,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 1},
#   {'group': 'train',
#    'iter': 90,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.003703703703703704},
#   {'group': 'valid',
#    'iter': 91,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.31591108441352844},
#   {'group': 'valid',
#    'iter': 91,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 81.84818481848185},
#   {'group': 'train',
#    'iter': 91,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 5},
#   {'group': 'train',
#    'iter': 91,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 92,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.13846921920776367},
#   {'group': 'valid',
#    'iter': 92,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 98.67986798679867},
#   {'group': 'train',
#    'iter': 92,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 5},
#   {'group': 'train',
#    'iter': 92,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 93,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.13641953468322754},
#   {'group': 'valid',
#    'iter': 93,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 99.00990099009901},
#   {'group': 'train',
#    'iter': 93,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 5},
#   {'group': 'train',
#    'iter': 93,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.0012345679012345679},
#   {'group': 'valid',
#    'iter': 94,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-03-23-06',
#    'value': 0.13579733669757843},
#   {'group': 'valid',
#    'iter': 94,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-03-23-06',
# ...
#   {'group': 'train',
#    'iter': 18,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-28',
#    'value': 2},
#   {'group': 'train',
#    'iter': 18,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-28',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 1.091653823852539},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 65.27331189710611},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 1},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.7928652763366699},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 82.31511254019293},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 1.1646250486373901},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 65.27331189710611},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 4},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.7447757720947266},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 84.88745980707395},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.8644707202911377},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 70.09646302250803},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 4},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.7405980825424194},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 87.78135048231512},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.7505841255187988},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 85.85209003215434},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 4},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 1.1828893423080444},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 65.27331189710611},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 3},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.7618482112884521},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 82.63665594855306},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 2},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.9421422481536865},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 68.81028938906752},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 1},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.8019448518753052},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 78.77813504823152},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6873534917831421},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 88.42443729903538},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6766188740730286},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 88.10289389067523},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.664318323135376},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 90.35369774919614},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6681454181671143},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 87.13826366559485},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 4},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6535834074020386},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 88.10289389067523},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6458514332771301},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 90.03215434083602},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6801928281784058},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 86.81672025723472},
#   {'group': 'train',
#    'iter': 36,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 4},
#   {'group': 'train',
#    'iter': 36,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 37,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6422305107116699},
#   {'group': 'valid',
#    'iter': 37,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 89.06752411575563},
#   {'group': 'train',
#    'iter': 37,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 37,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 38,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6451089382171631},
#   {'group': 'valid',
#    'iter': 38,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 89.38906752411575},
#   {'group': 'train',
#    'iter': 38,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 4},
#   {'group': 'train',
#    'iter': 38,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 39,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6380190849304199},
#   {'group': 'valid',
#    'iter': 39,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 89.06752411575563},
#   {'group': 'train',
#    'iter': 39,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 39,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 40,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.632224440574646},
#   {'group': 'valid',
#    'iter': 40,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 90.03215434083602},
#   {'group': 'train',
#    'iter': 40,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 40,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 41,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6388699412345886},
#   {'group': 'valid',
#    'iter': 41,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 88.10289389067523},
#   {'group': 'train',
#    'iter': 41,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 4},
#   {'group': 'train',
#    'iter': 41,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 42,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.63170325756073},
#   {'group': 'valid',
#    'iter': 42,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 90.03215434083602},
#   {'group': 'train',
#    'iter': 42,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 42,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 43,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6320660710334778},
#   {'group': 'valid',
#    'iter': 43,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 89.71061093247589},
#   {'group': 'train',
#    'iter': 43,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 4},
#   {'group': 'train',
#    'iter': 43,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 44,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6287556886672974},
#   {'group': 'valid',
#    'iter': 44,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 89.38906752411575},
#   {'group': 'train',
#    'iter': 44,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   {'group': 'train',
#    'iter': 44,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 45,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6665976047515869},
#   {'group': 'valid',
#    'iter': 45,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 87.78135048231512},
#   {'group': 'train',
#    'iter': 45,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 4},
#   {'group': 'train',
#    'iter': 45,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 46,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6490991115570068},
#   {'group': 'valid',
#    'iter': 46,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 88.10289389067523},
#   {'group': 'train',
#    'iter': 46,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 3},
#   {'group': 'train',
#    'iter': 46,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 47,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6746360063552856},
#   {'group': 'valid',
#    'iter': 47,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 87.13826366559485},
#   {'group': 'train',
#    'iter': 47,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 2},
#   {'group': 'train',
#    'iter': 47,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 48,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6918936371803284},
#   {'group': 'valid',
#    'iter': 48,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 86.81672025723472},
#   {'group': 'train',
#    'iter': 48,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 1},
#   {'group': 'train',
#    'iter': 48,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.0033333333333333335},
#   {'group': 'valid',
#    'iter': 49,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 0.6311280727386475},
#   {'group': 'valid',
#    'iter': 49,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 89.38906752411575},
#   {'group': 'train',
#    'iter': 49,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-04-00-29',
#    'value': 5},
#   ...]}

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_tag" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
len(res_dict)
# Out:
# 3

# %%
import pandas as pd
import numpy as np
from itertools import chain
data = pd.DataFrame({'Approach': list(chain.from_iterable([['LWF' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
import seaborn as sns
sns.lineplot( data,  x='Task', y='Average Accuracy', ci=None)
# Out:
# /tmp/ipykernel_38302/1207693049.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot( data,  x='Task', y='Average Accuracy', ci=None)
# <Axes: xlabel='Task', ylabel='Average Accuracy'>

# %%
data.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# LWF      0                96.70                 NaN
#          1                76.39               34.52
#          2                74.82               21.83
#          3                57.21               37.22

# %%
path_ewc = '/home/karokaro/research-repositories/FACIL/results/bloodmnist_ewc_final_bloodmnist'

# %%
onlyfiles = [f for f in listdir(path_ewc) if isfile(join(path_ewc, f))]
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_ewc, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_ewc, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_tag" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
data_ewc = pd.DataFrame({'Approach': list(chain.from_iterable([['EWC' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
sns.lineplot( data_ewc,  x='Task', y='Average Accuracy')
# Out:
# <Axes: xlabel='Task', ylabel='Average Accuracy'>

# %%
data_ewc.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# EWC      0                96.51                 NaN
#          1                74.14               38.56
#          2                72.19               33.18
#          3                67.86               37.06

# %%
path_lwm = '/home/karokaro/research-repositories/FACIL/results/bloodmnist_lwm_final_bloodmnist'

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(path_lwm) if isfile(join(path_lwm, f))]
onlyfiles
# Out:
# ['raw_log-2025-02-03-18-40.txt',
#  'stderr-2025-02-03-19-08.txt',
#  'stderr-2025-02-03-18-20.txt',
#  'raw_log-2025-02-03-20-22.txt',
#  'stdout-2025-02-03-20-10.txt',
#  'raw_log-2025-02-03-20-10.txt',
#  'stderr-2025-02-03-19-22.txt',
#  'stdout-2025-02-03-19-56.txt',
#  'stdout-2025-02-03-20-22.txt',
#  'raw_log-2025-02-03-18-55.txt',
#  'stderr-2025-02-03-18-55.txt',
#  'raw_log-2025-02-03-19-40.txt',
#  'raw_log-2025-02-03-18-20.txt',
#  'stdout-2025-02-03-19-40.txt',
#  'raw_log-2025-02-03-19-22.txt',
#  'stdout-2025-02-03-19-22.txt',
#  'raw_log-2025-02-03-19-08.txt',
#  'stdout-2025-02-03-18-55.txt',
#  'args-2025-02-03-20-10.txt',
#  'stderr-2025-02-03-20-22.txt',
#  'args-2025-02-03-19-56.txt',
#  'stdout-2025-02-03-18-20.txt',
#  'args-2025-02-03-19-08.txt',
#  'args-2025-02-03-19-22.txt',
#  'stderr-2025-02-03-19-40.txt',
#  'args-2025-02-03-18-40.txt',
#  'raw_log-2025-02-03-19-56.txt',
#  'args-2025-02-03-20-22.txt',
#  'stdout-2025-02-03-18-40.txt',
#  'args-2025-02-03-18-20.txt',
#  'args-2025-02-03-19-40.txt',
#  'args-2025-02-03-18-55.txt',
#  'stderr-2025-02-03-20-10.txt',
#  'stdout-2025-02-03-19-08.txt',
#  'stderr-2025-02-03-18-40.txt',
#  'stderr-2025-02-03-19-56.txt']

# %%
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_lwm, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_lwm, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_tag" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
import pandas as pd
import numpy as np
from itertools import chain
data_lwm = pd.DataFrame({'Approach': list(chain.from_iterable([['LWM' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
sns.lineplot( data_lwm,  x='Task', y='Average Accuracy')
# Out:
# <Axes: xlabel='Task', ylabel='Average Accuracy'>

# %%
data_lwm.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# LWM      0                95.20                 NaN
#          1                86.44               12.29
#          2                80.99               19.35
#          3                71.58               27.21

# %%
path_icarl = '/home/karokaro/research-repositories/FACIL/results/bloodmnist_icarl_final_bloodmnist'

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(path_icarl) if isfile(join(path_icarl, f))]
onlyfiles
# Out:
# ['stderr-2025-02-03-23-34.txt',
#  'stderr-2025-02-03-23-09.txt',
#  'raw_log-2025-02-03-22-33.txt',
#  'stderr-2025-02-03-22-33.txt',
#  'stderr-2025-02-03-22-20.txt',
#  'raw_log-2025-02-03-23-34.txt',
#  'stderr-2025-02-03-23-22.txt',
#  'args-2025-02-03-23-22.txt',
#  'args-2025-02-03-22-45.txt',
#  'args-2025-02-03-22-58.txt',
#  'raw_log-2025-02-03-23-22.txt',
#  'stderr-2025-02-03-22-58.txt',
#  'args-2025-02-03-23-09.txt',
#  'stderr-2025-02-03-22-45.txt',
#  'stdout-2025-02-03-23-44.txt',
#  'args-2025-02-03-22-33.txt',
#  'stderr-2025-02-03-23-44.txt',
#  'stdout-2025-02-03-22-33.txt',
#  'args-2025-02-03-23-34.txt',
#  'stdout-2025-02-03-22-45.txt',
#  'stdout-2025-02-03-22-09.txt',
#  'raw_log-2025-02-03-23-44.txt',
#  'args-2025-02-03-22-20.txt',
#  'args-2025-02-03-23-44.txt',
#  'raw_log-2025-02-03-22-45.txt',
#  'stderr-2025-02-03-22-09.txt',
#  'raw_log-2025-02-03-22-58.txt',
#  'raw_log-2025-02-03-22-09.txt',
#  'raw_log-2025-02-03-22-20.txt',
#  'stdout-2025-02-03-23-34.txt',
#  'raw_log-2025-02-03-23-09.txt',
#  'args-2025-02-03-22-09.txt',
#  'stdout-2025-02-03-23-22.txt',
#  'stdout-2025-02-03-22-20.txt',
#  'stdout-2025-02-03-23-09.txt',
#  'stdout-2025-02-03-22-58.txt']

# %%
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_icarl, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_icarl, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_tag" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
import pandas as pd
import numpy as np
from itertools import chain
data_icarl = pd.DataFrame({'Approach': list(chain.from_iterable([['iCaRL' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
data_icarl.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# iCaRL    0                97.70                 NaN
#          1                87.78               10.64
#          2                92.05                1.52
#          3                92.52                3.37

# %%
path_rere = '/home/karokaro/research-repositories/FACIL/results/bloodmnist_rere_lrp_final_bloodmnist'

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(path_rere) if isfile(join(path_rere, f))]
onlyfiles
# Out:
# ['stderr-2025-02-04-19-03.txt',
#  'args-2025-02-04-17-24.txt',
#  'args-2025-02-04-16-20.txt',
#  'args-2025-02-04-15-48.txt',
#  'stdout-2025-02-04-15-25.txt',
#  'stdout-2025-02-04-17-24.txt',
#  'args-2025-02-04-19-03.txt',
#  'stdout-2025-02-04-16-20.txt',
#  'stdout-2025-02-04-17-55.txt',
#  'stderr-2025-02-04-15-48.txt',
#  'raw_log-2025-02-04-16-20.txt',
#  'raw_log-2025-02-04-14-55.txt',
#  'stdout-2025-02-04-19-03.txt',
#  'stderr-2025-02-04-17-24.txt',
#  'args-2025-02-04-14-55.txt',
#  'raw_log-2025-02-04-15-48.txt',
#  'stderr-2025-02-04-16-57.txt',
#  'raw_log-2025-02-04-16-57.txt',
#  'stderr-2025-02-04-15-25.txt',
#  'stderr-2025-02-04-14-55.txt',
#  'raw_log-2025-02-04-15-25.txt',
#  'stderr-2025-02-04-18-30.txt',
#  'args-2025-02-04-16-57.txt',
#  'stderr-2025-02-04-16-20.txt',
#  'args-2025-02-04-18-30.txt',
#  'stdout-2025-02-04-16-57.txt',
#  'args-2025-02-04-15-25.txt',
#  'stdout-2025-02-04-15-48.txt',
#  'stdout-2025-02-04-18-30.txt',
#  'raw_log-2025-02-04-17-55.txt',
#  'raw_log-2025-02-04-19-03.txt',
#  'stdout-2025-02-04-14-55.txt',
#  'stderr-2025-02-04-17-55.txt',
#  'raw_log-2025-02-04-18-30.txt',
#  'raw_log-2025-02-04-17-24.txt',
#  'args-2025-02-04-17-55.txt']

# %%
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_rere, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_rere, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_tag" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
data_rere = pd.DataFrame({'Approach': list(chain.from_iterable([['ReReLRP' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
sns.lineplot( data_rere,  x='Task', y='Average Accuracy')
# Out:
# <Axes: xlabel='Task', ylabel='Average Accuracy'>

# %%
data_rere.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# ReReLRP  0                96.66                 NaN
#          1                91.72                1.42
#          2                92.39                0.71
#          3                93.71                0.47

# %%
path_lwm = '/home/karokaro/research-repositories/FACIL/results/bloodmnist_joint_finetune_bloodmnist'

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(path_lwm) if isfile(join(path_lwm, f))]
onlyfiles
# Out:
# ['raw_log-2025-02-05-20-21.txt',
#  'raw_log-2025-02-05-18-01.txt',
#  'args-2025-02-05-19-13.txt',
#  'stdout-2025-02-05-18-13.txt',
#  'args-2025-02-05-20-08.txt',
#  'raw_log-2025-02-05-18-13.txt',
#  'args-2025-02-05-20-21.txt',
#  'stdout-2025-02-05-18-57.txt',
#  'stderr-2025-02-05-20-21.txt',
#  'args-2025-02-05-19-48.txt',
#  'stderr-2025-02-05-18-32.txt',
#  'stdout-2025-02-05-19-48.txt',
#  'args-2025-02-05-18-01.txt',
#  'args-2025-02-05-18-13.txt',
#  'raw_log-2025-02-05-18-32.txt',
#  'raw_log-2025-02-05-18-57.txt',
#  'stdout-2025-02-05-19-13.txt',
#  'stdout-2025-02-05-18-01.txt',
#  'raw_log-2025-02-05-19-48.txt',
#  'raw_log-2025-02-05-20-08.txt',
#  'stderr-2025-02-05-18-01.txt',
#  'stdout-2025-02-05-20-08.txt',
#  'stdout-2025-02-05-18-32.txt',
#  'stderr-2025-02-05-19-13.txt',
#  'stderr-2025-02-05-18-57.txt',
#  'stderr-2025-02-05-19-32.txt',
#  'stderr-2025-02-05-20-08.txt',
#  'raw_log-2025-02-05-19-32.txt',
#  'stderr-2025-02-05-18-13.txt',
#  'args-2025-02-05-18-32.txt',
#  'stdout-2025-02-05-19-32.txt',
#  'stdout-2025-02-05-20-21.txt',
#  'args-2025-02-05-19-32.txt',
#  'stderr-2025-02-05-19-48.txt',
#  'args-2025-02-05-18-57.txt',
#  'raw_log-2025-02-05-19-13.txt']

# %%
args = [file for file in onlyfiles if 'args' in file ]
len(args)
# Out:
# 9

# %%
import json
arg_dict = {}
for file in args:
    with open(join(path_lwm, file), 'r') as f:
        # regex time! we need only the timestamp of the file
        name = file.split('args-')[1]
        arg_dict[name] = json.loads(f.read())

# %%
import json

logs = [file for file in onlyfiles if 'raw_log' in file ]

res_dict = {}
for file in logs:
    with open(join(path_lwm, file), 'r') as f:
        name = file.split('raw_log-')[1]
        res_dict[name] = []
        for line in f:
            res_dict[name].append(json.loads(line.strip()))

# %%
res_dict
# Out:
# {'2025-02-05-20-21.txt': [{'group': 'valid',
#    'iter': 1,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.6446908116340637},
#   {'group': 'valid',
#    'iter': 1,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 1,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.6088526844978333},
#   {'group': 'valid',
#    'iter': 2,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 2,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5942175388336182},
#   {'group': 'valid',
#    'iter': 3,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 3,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5925267338752747},
#   {'group': 'valid',
#    'iter': 4,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 4,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5929776430130005},
#   {'group': 'valid',
#    'iter': 5,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 5,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5923388600349426},
#   {'group': 'valid',
#    'iter': 6,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 6,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 7,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5918999314308167},
#   {'group': 'valid',
#    'iter': 7,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 7,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 7,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 8,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5920509099960327},
#   {'group': 'valid',
#    'iter': 8,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 8,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 8,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 9,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5913267135620117},
#   {'group': 'valid',
#    'iter': 9,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 9,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 9,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 10,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.591032087802887},
#   {'group': 'valid',
#    'iter': 10,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 10,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 10,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 11,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5911613702774048},
#   {'group': 'valid',
#    'iter': 11,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 11,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 11,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 12,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5905776619911194},
#   {'group': 'valid',
#    'iter': 12,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 12,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 12,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 13,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5904300212860107},
#   {'group': 'valid',
#    'iter': 13,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 13,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 13,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 14,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5901586413383484},
#   {'group': 'valid',
#    'iter': 14,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 14,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 14,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 15,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5899549722671509},
#   {'group': 'valid',
#    'iter': 15,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 15,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 15,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 16,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5900362133979797},
#   {'group': 'valid',
#    'iter': 16,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 16,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 16,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 17,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5903809070587158},
#   {'group': 'valid',
#    'iter': 17,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 17,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 3},
#   {'group': 'train',
#    'iter': 17,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 18,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5893117189407349},
#   {'group': 'valid',
#    'iter': 18,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 18,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 18,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5893669724464417},
#   {'group': 'valid',
#    'iter': 19,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 19,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5892813801765442},
#   {'group': 'valid',
#    'iter': 20,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 20,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5889021158218384},
#   {'group': 'valid',
#    'iter': 21,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 21,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5896638035774231},
#   {'group': 'valid',
#    'iter': 22,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 22,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5880337953567505},
#   {'group': 'valid',
#    'iter': 23,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 23,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5892292857170105},
#   {'group': 'valid',
#    'iter': 24,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 24,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5885937809944153},
#   {'group': 'valid',
#    'iter': 25,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 3},
#   {'group': 'train',
#    'iter': 25,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5888510346412659},
#   {'group': 'valid',
#    'iter': 26,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 2},
#   {'group': 'train',
#    'iter': 26,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5876125693321228},
#   {'group': 'valid',
#    'iter': 27,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 27,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.586937665939331},
#   {'group': 'valid',
#    'iter': 28,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 28,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5870440006256104},
#   {'group': 'valid',
#    'iter': 29,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 29,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5863661170005798},
#   {'group': 'valid',
#    'iter': 30,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 30,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5864607095718384},
#   {'group': 'valid',
#    'iter': 31,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 31,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5863282084465027},
#   {'group': 'valid',
#    'iter': 32,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 32,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5857549905776978},
#   {'group': 'valid',
#    'iter': 33,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 33,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5863769054412842},
#   {'group': 'valid',
#    'iter': 34,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 34,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5850653052330017},
#   {'group': 'valid',
#    'iter': 35,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 35,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5849034786224365},
#   {'group': 'valid',
#    'iter': 36,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 36,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 36,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 37,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5854860544204712},
#   {'group': 'valid',
#    'iter': 37,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 37,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 37,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 38,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5842331051826477},
#   {'group': 'valid',
#    'iter': 38,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 38,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 38,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 39,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5841241478919983},
#   {'group': 'valid',
#    'iter': 39,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 39,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 39,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 40,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5837032794952393},
#   {'group': 'valid',
#    'iter': 40,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 40,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 40,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 41,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.5853691697120667},
#   {'group': 'valid',
#    'iter': 41,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 41,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 41,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-21',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 42,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5829852223396301},
#   {'group': 'valid',
#    'iter': 42,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 42,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 42,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 43,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5843324065208435},
#   {'group': 'valid',
#    'iter': 43,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 43,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 4},
#   {'group': 'train',
#    'iter': 43,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 44,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5835740566253662},
#   {'group': 'valid',
#    'iter': 44,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 44,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 3},
#   {'group': 'train',
#    'iter': 44,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 45,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5823511481285095},
#   {'group': 'valid',
#    'iter': 45,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 45,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 45,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 46,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5816363096237183},
#   {'group': 'valid',
#    'iter': 46,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 46,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 46,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 47,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.581140398979187},
#   {'group': 'valid',
#    'iter': 47,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 47,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 47,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 48,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.581615686416626},
#   {'group': 'valid',
#    'iter': 48,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 48,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 4},
#   {'group': 'train',
#    'iter': 48,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 49,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.580389142036438},
#   {'group': 'valid',
#    'iter': 49,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 49,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 49,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 50,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5805974006652832},
#   {'group': 'valid',
#    'iter': 50,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 50,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 4},
#   {'group': 'train',
#    'iter': 50,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 51,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5803378820419312},
#   {'group': 'valid',
#    'iter': 51,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 51,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 51,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 52,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5803447365760803},
#   {'group': 'valid',
#    'iter': 52,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 52,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 4},
#   {'group': 'train',
#    'iter': 52,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 53,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5787599086761475},
#   {'group': 'valid',
#    'iter': 53,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 53,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 53,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 54,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5799773335456848},
#   {'group': 'valid',
#    'iter': 54,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 54,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 4},
#   {'group': 'train',
#    'iter': 54,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 55,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5774974822998047},
#   {'group': 'valid',
#    'iter': 55,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 55,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 55,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 56,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5783084630966187},
#   {'group': 'valid',
#    'iter': 56,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 56,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 4},
#   {'group': 'train',
#    'iter': 56,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 57,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5787772536277771},
#   {'group': 'valid',
#    'iter': 57,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 57,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 3},
#   {'group': 'train',
#    'iter': 57,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 58,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5772849321365356},
#   {'group': 'valid',
#    'iter': 58,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 58,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 58,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 59,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5750311613082886},
#   {'group': 'valid',
#    'iter': 59,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 59,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 59,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 60,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5743518471717834},
#   {'group': 'valid',
#    'iter': 60,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 60,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 60,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 61,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5748082399368286},
#   {'group': 'valid',
#    'iter': 61,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 61,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 4},
#   {'group': 'train',
#    'iter': 61,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 62,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5732025504112244},
#   {'group': 'valid',
#    'iter': 62,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 62,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 62,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 63,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.572198748588562},
#   {'group': 'valid',
#    'iter': 63,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 63,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 63,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 64,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5719071626663208},
#   {'group': 'valid',
#    'iter': 64,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 64,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 64,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 65,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5718529224395752},
#   {'group': 'valid',
#    'iter': 65,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 65,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 65,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 66,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.569802463054657},
#   {'group': 'valid',
#    'iter': 66,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 66,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 66,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 67,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5697304010391235},
#   {'group': 'valid',
#    'iter': 67,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 67,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 67,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 68,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5680819749832153},
#   {'group': 'valid',
#    'iter': 68,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 68,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 68,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 69,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5668010711669922},
#   {'group': 'valid',
#    'iter': 69,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 69,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 69,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 70,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5692367553710938},
#   {'group': 'valid',
#    'iter': 70,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 70,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 4},
#   {'group': 'train',
#    'iter': 70,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 71,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5643620491027832},
#   {'group': 'valid',
#    'iter': 71,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 71,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 71,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 72,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5641230940818787},
#   {'group': 'valid',
#    'iter': 72,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 72,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 72,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 73,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5617421865463257},
#   {'group': 'valid',
#    'iter': 73,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 73,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 73,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 74,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5602173209190369},
#   {'group': 'valid',
#    'iter': 74,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 74,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 74,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 75,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.560001015663147},
#   {'group': 'valid',
#    'iter': 75,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 75,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 75,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 76,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5584611296653748},
#   {'group': 'valid',
#    'iter': 76,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 76,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 76,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 77,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5554679036140442},
#   {'group': 'valid',
#    'iter': 77,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 77,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 77,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 78,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5556597709655762},
#   {'group': 'valid',
#    'iter': 78,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 78,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 4},
#   {'group': 'train',
#    'iter': 78,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 79,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5519498586654663},
#   {'group': 'valid',
#    'iter': 79,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 79,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 79,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 80,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5498157739639282},
#   {'group': 'valid',
#    'iter': 80,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 80,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 80,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 81,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5488136410713196},
#   {'group': 'valid',
#    'iter': 81,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 81,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 81,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 82,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.544676661491394},
#   {'group': 'valid',
#    'iter': 82,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 82,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 82,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 83,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5418050289154053},
#   {'group': 'valid',
#    'iter': 83,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 83,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 83,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 84,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5423682332038879},
#   {'group': 'valid',
#    'iter': 84,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 84,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 4},
#   {'group': 'train',
#    'iter': 84,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 85,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5354347229003906},
#   {'group': 'valid',
#    'iter': 85,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 85,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 5},
#   {'group': 'train',
#    'iter': 85,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 86,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.5460425615310669},
#   {'group': 'valid',
#    'iter': 86,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 86,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 4},
#   {'group': 'train',
#    'iter': 86,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-22',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 87,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.580349326133728},
#   {'group': 'valid',
#    'iter': 87,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 87,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 3},
#   {'group': 'train',
#    'iter': 87,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 88,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.531933605670929},
#   {'group': 'valid',
#    'iter': 88,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 88,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 5},
#   {'group': 'train',
#    'iter': 88,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 89,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.52717524766922},
#   {'group': 'valid',
#    'iter': 89,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 89,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 5},
#   {'group': 'train',
#    'iter': 89,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 90,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.5651674270629883},
#   {'group': 'valid',
#    'iter': 90,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 90,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 4},
#   {'group': 'train',
#    'iter': 90,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 91,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.512968897819519},
#   {'group': 'valid',
#    'iter': 91,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 91,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 5},
#   {'group': 'train',
#    'iter': 91,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 92,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.5083788633346558},
#   {'group': 'valid',
#    'iter': 92,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 92,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 5},
#   {'group': 'train',
#    'iter': 92,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 93,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.5406557321548462},
#   {'group': 'valid',
#    'iter': 93,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 93,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 4},
#   {'group': 'train',
#    'iter': 93,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 94,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.49979230761528015},
#   {'group': 'valid',
#    'iter': 94,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 94,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 5},
#   {'group': 'train',
#    'iter': 94,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 95,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.49319207668304443},
#   {'group': 'valid',
#    'iter': 95,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 71.94719471947195},
#   {'group': 'train',
#    'iter': 95,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 5},
#   {'group': 'train',
#    'iter': 95,
#    'name': 'lr',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.01},
#   {'group': 'valid',
#    'iter': 96,
#    'name': 'loss',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 0.628966748714447},
#   {'group': 'valid',
#    'iter': 96,
#    'name': 'acc',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 96.03960396039604},
#   {'group': 'train',
#    'iter': 96,
#    'name': 'patience',
#    'task': 0,
#    'time': '2025-02-05-20-23',
#    'value': 4},
#   {'group': 'train',
#    'iter': 96,
# ...
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 92.99674267100977},
#   {'group': 'train',
#    'iter': 68,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 68,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 69,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6573090448441645},
#   {'group': 'valid',
#    'iter': 69,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 93.32247557003257},
#   {'group': 'train',
#    'iter': 69,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 69,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 70,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6445852242385914},
#   {'group': 'valid',
#    'iter': 70,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 92.99674267100977},
#   {'group': 'train',
#    'iter': 70,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 70,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 71,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.7024999732691612},
#   {'group': 'valid',
#    'iter': 71,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 92.50814332247556},
#   {'group': 'train',
#    'iter': 71,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 71,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 72,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6798408507135869},
#   {'group': 'valid',
#    'iter': 72,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 92.34527687296416},
#   {'group': 'train',
#    'iter': 72,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 3},
#   {'group': 'train',
#    'iter': 72,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 73,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6899433572828187},
#   {'group': 'valid',
#    'iter': 73,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 93.32247557003257},
#   {'group': 'train',
#    'iter': 73,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 2},
#   {'group': 'train',
#    'iter': 73,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 74,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6313128030649614},
#   {'group': 'valid',
#    'iter': 74,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 93.32247557003257},
#   {'group': 'train',
#    'iter': 74,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 74,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 75,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6782234118893403},
#   {'group': 'valid',
#    'iter': 75,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 93.32247557003257},
#   {'group': 'train',
#    'iter': 75,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 75,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 76,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6851993521572324},
#   {'group': 'valid',
#    'iter': 76,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 93.48534201954396},
#   {'group': 'train',
#    'iter': 76,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 3},
#   {'group': 'train',
#    'iter': 76,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 77,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6253316891698185},
#   {'group': 'valid',
#    'iter': 77,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 94.13680781758957},
#   {'group': 'train',
#    'iter': 77,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 77,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 78,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.7392735933636221},
#   {'group': 'valid',
#    'iter': 78,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 92.67100977198697},
#   {'group': 'train',
#    'iter': 78,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 78,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 79,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6617467005400394},
#   {'group': 'valid',
#    'iter': 79,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 93.81107491856677},
#   {'group': 'train',
#    'iter': 79,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 3},
#   {'group': 'train',
#    'iter': 79,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 80,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6218890567167574},
#   {'group': 'valid',
#    'iter': 80,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 94.13680781758957},
#   {'group': 'train',
#    'iter': 80,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 80,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 81,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6499901219765604},
#   {'group': 'valid',
#    'iter': 81,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 93.48534201954396},
#   {'group': 'train',
#    'iter': 81,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 81,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 82,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.674785954362018},
#   {'group': 'valid',
#    'iter': 82,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 93.64820846905538},
#   {'group': 'train',
#    'iter': 82,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 3},
#   {'group': 'train',
#    'iter': 82,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 83,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6194103608690567},
#   {'group': 'valid',
#    'iter': 83,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 94.29967426710097},
#   {'group': 'train',
#    'iter': 83,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 83,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 84,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6425202850021835},
#   {'group': 'valid',
#    'iter': 84,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 93.15960912052117},
#   {'group': 'train',
#    'iter': 84,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 84,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 85,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.8434795020845891},
#   {'group': 'valid',
#    'iter': 85,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 89.41368078175896},
#   {'group': 'train',
#    'iter': 85,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 3},
#   {'group': 'train',
#    'iter': 85,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 86,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.5840258615801311},
#   {'group': 'valid',
#    'iter': 86,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 94.29967426710097},
#   {'group': 'train',
#    'iter': 86,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 86,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 87,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6354742017165069},
#   {'group': 'valid',
#    'iter': 87,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 91.53094462540716},
#   {'group': 'train',
#    'iter': 87,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 87,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 88,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.6052454692533039},
#   {'group': 'valid',
#    'iter': 88,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 94.13680781758957},
#   {'group': 'train',
#    'iter': 88,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 3},
#   {'group': 'train',
#    'iter': 88,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 89,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.7507236904740722},
#   {'group': 'valid',
#    'iter': 89,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 91.20521172638436},
#   {'group': 'train',
#    'iter': 89,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 2},
#   {'group': 'train',
#    'iter': 89,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 90,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.5858489935095225},
#   {'group': 'valid',
#    'iter': 90,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 93.64820846905538},
#   {'group': 'train',
#    'iter': 90,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 1},
#   {'group': 'train',
#    'iter': 90,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.005555555555555556},
#   {'group': 'valid',
#    'iter': 91,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.8315056465347738},
#   {'group': 'valid',
#    'iter': 91,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 89.41368078175896},
#   {'group': 'train',
#    'iter': 91,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 5},
#   {'group': 'train',
#    'iter': 91,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 92,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.5879865224664297},
#   {'group': 'valid',
#    'iter': 92,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 93.48534201954396},
#   {'group': 'train',
#    'iter': 92,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 4},
#   {'group': 'train',
#    'iter': 92,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 93,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.5845774829581817},
#   {'group': 'valid',
#    'iter': 93,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 94.13680781758957},
#   {'group': 'train',
#    'iter': 93,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 3},
#   {'group': 'train',
#    'iter': 93,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-20',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 94,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 0.5850610490342305},
#   {'group': 'valid',
#    'iter': 94,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 94.13680781758957},
#   {'group': 'train',
#    'iter': 94,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 2},
#   {'group': 'train',
#    'iter': 94,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 95,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 0.5794870818476724},
#   {'group': 'valid',
#    'iter': 95,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 94.13680781758957},
#   {'group': 'train',
#    'iter': 95,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 95,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 96,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 0.5871548076017672},
#   {'group': 'valid',
#    'iter': 96,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 93.64820846905538},
#   {'group': 'train',
#    'iter': 96,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 4},
#   {'group': 'train',
#    'iter': 96,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 97,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 0.5815225907568046},
#   {'group': 'valid',
#    'iter': 97,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 94.13680781758957},
#   {'group': 'train',
#    'iter': 97,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 3},
#   {'group': 'train',
#    'iter': 97,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 98,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 0.5760442744637156},
#   {'group': 'valid',
#    'iter': 98,
#    'name': 'acc',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 94.29967426710097},
#   {'group': 'train',
#    'iter': 98,
#    'name': 'patience',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 5},
#   {'group': 'train',
#    'iter': 98,
#    'name': 'lr',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 0.001851851851851852},
#   {'group': 'valid',
#    'iter': 99,
#    'name': 'loss',
#    'task': 1,
#    'time': '2025-02-05-19-21',
#    'value': 0.5834658083775921},
#   ...]}

# %%
import numpy as np
seeds = [0, 1, 2]
for seed in seeds:
    small = [key for key in arg_dict if arg_dict[key]["seed"]==seed]
    arg_means = {key:[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in [3]] for key in small}
    max_key = max(arg_means, key=arg_means.get)
    small.remove(max_key)
    for key in small:
        res_dict.pop(key)
        arg_dict.pop(key)

# %%
import pandas as pd
import numpy as np
from itertools import chain
data_joint = pd.DataFrame({'Approach': list(chain.from_iterable([['Joint' for i in range(4)] for key in res_dict.keys()])),
                     'Task': list(chain.from_iterable([[i for i in range(4)] for key in res_dict.keys()])),
                     'Average Accuracy': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="acc_taw" and k["group"]=="test" and k["task"] == i]) for i in range(4)] for key in res_dict.keys()])),
                     'Average Forgetting': list(chain.from_iterable([[np.mean([k["value"] for k in res_dict[key] if k["name"]=="forg_taw" and k["group"]=="test" and k["task"] == i and k["iter"] != k["task"]]) for i in range(4)] for key in res_dict.keys()]))})
# Out:
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/karokaro/research-repositories/FACIL/venv/lib/python3.11/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
sns.lineplot( data_joint,  x='Task', y='Average Accuracy', ci=None)
# Out:
# /tmp/ipykernel_38302/2585113533.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot( data_joint,  x='Task', y='Average Accuracy', ci=None)
# <Axes: xlabel='Task', ylabel='Average Accuracy'>

# %%
data_joint.groupby(['Approach', 'Task']).mean().apply(lambda x: round(x, 2))
# Out:
#                Average Accuracy  Average Forgetting
# Approach Task
# Joint    0                95.24                 NaN
#          1                94.43               -2.61
#          2                93.67                0.45
#          3                96.40               -1.02

# %%
data_all = pd.concat([data, data_ewc, data_icarl, data_rere, data_joint, data_lwm], ignore_index=True)

# %%
import matplotlib.pyplot as plt
hue_order = ["LWM", "LWF", "EWC", "iCaRL", "ReReLRP", "Joint"]
paletter = sns.color_palette("colorblind", 6)
sns.set_theme(style="ticks", font_scale=1.3) 
g = sns.lineplot( data_all, hue='Approach', x='Task', y='Average Accuracy', hue_order=hue_order, ci=None)
g.set_xticks(range(4))
g.set_xticklabels([i+1 for i in range(4)])
import matplotlib.ticker as mtick
g.yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0))

plt.savefig("bloodmnist_taw.pdf", format='pdf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_38302/1873445578.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   g = sns.lineplot( data_all, hue='Approach', x='Task', y='Average Accuracy', hue_order=hue_order, ci=None)
